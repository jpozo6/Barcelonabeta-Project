# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import os

# %% [markdown]
# ## Describing FastSurfer subjects stats

# %%
statsFastS = pd.read_csv('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/aseg_stats.csv')

# %%
statsFastS.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0               0                 15027.1              641.9
# 1               1                 15028.7              809.5
# 2               2                 10931.6              760.5
# 3               3                 21022.3              886.6
# 4               4                  7773.4              533.2
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       14518.4                 49024.5                5880.1
# 1                       14101.8                 49310.6                6153.4
# 2                       13588.4                 56167.5                7061.4
# 3                       11670.9                 40964.6                6156.1
# 4                       14658.8                 49447.8                7429.0
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        3105.0        5069.1         1769.0         1961.1  ...
# 1        3034.4        4836.5         1647.6         1939.1  ...
# 2        3354.8        5029.7         2194.0         2335.3  ...
# 3        2948.7        4228.8         1666.8         2017.8  ...
# 4        2861.1        4758.4         1898.1         1020.2  ...
#
#    SupraTentorialVol  SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  \
# 0       9.508758e+05              9.194948e+05                       918107
# 1       9.577320e+05              9.265220e+05                       924839
# 2       1.066739e+06              1.041607e+06                      1039981
# 3       1.002746e+06              9.567843e+05                       956002
# 4       1.077000e+06              1.059472e+06                      1057021
#
#    MaskVol  BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  \
# 0  1372434             0.708702         0.903141              21
# 1  1375126             0.715196         0.907273              46
# 2  1478575             0.716136         0.877372              28
# 3  1442353             0.697698         0.905868              23
# 4  1474878             0.735471         0.900720              11
#
#    rhSurfaceHoles  SurfaceHoles  EstimatedTotalIntraCranialVol
# 0              23            44                   1.519623e+06
# 1              24            70                   1.515670e+06
# 2              17            45                   1.685232e+06
# 3              29            52                   1.592233e+06
# 4              12            23                   1.637444e+06
#
# [5 rows x 67 columns]

# %%
names = []
for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/Archivos_ALFAPLUS_security_copy'):
    sorted_files = sorted(files)
    for filename in sorted_files:

        #f = os.path.join(path, filename)
        #a.write('-i ' + str(filename.removesuffix('.nii.gz')) + '/stats/aseg.stats' + ' ') 

        names.append(int(filename[0:5]))
for i in range(0,391):
    statsFastS["Measure:volume"].replace({i: names[i]}, inplace=True)

statsFastS.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0           10013                 15027.1              641.9
# 1           10013                 15028.7              809.5
# 2           10019                 10931.6              760.5
# 3           10026                 21022.3              886.6
# 4           10032                  7773.4              533.2
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       14518.4                 49024.5                5880.1
# 1                       14101.8                 49310.6                6153.4
# 2                       13588.4                 56167.5                7061.4
# 3                       11670.9                 40964.6                6156.1
# 4                       14658.8                 49447.8                7429.0
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        3105.0        5069.1         1769.0         1961.1  ...
# 1        3034.4        4836.5         1647.6         1939.1  ...
# 2        3354.8        5029.7         2194.0         2335.3  ...
# 3        2948.7        4228.8         1666.8         2017.8  ...
# 4        2861.1        4758.4         1898.1         1020.2  ...
#
#    SupraTentorialVol  SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  \
# 0       9.508758e+05              9.194948e+05                       918107
# 1       9.577320e+05              9.265220e+05                       924839
# 2       1.066739e+06              1.041607e+06                      1039981
# 3       1.002746e+06              9.567843e+05                       956002
# 4       1.077000e+06              1.059472e+06                      1057021
#
#    MaskVol  BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  \
# 0  1372434             0.708702         0.903141              21
# 1  1375126             0.715196         0.907273              46
# 2  1478575             0.716136         0.877372              28
# 3  1442353             0.697698         0.905868              23
# 4  1474878             0.735471         0.900720              11
#
#    rhSurfaceHoles  SurfaceHoles  EstimatedTotalIntraCranialVol
# 0              23            44                   1.519623e+06
# 1              24            70                   1.515670e+06
# 2              17            45                   1.685232e+06
# 3              29            52                   1.592233e+06
# 4              12            23                   1.637444e+06
#
# [5 rows x 67 columns]

# %%
statsFastS.rename(columns={'Measure:volume': 'subject'}, inplace=True)
statsFastS.set_index('subject', inplace= True)

# %%
statsFastS.tail()
# Out:
#          Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# subject
# 77191                   14195.1              504.7
# 77224                    8944.4              850.7
# 77249                   12735.9              526.6
# 77296                   12039.4              906.9
# 77341                    5906.6              609.3
#
#          Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# subject
# 77191                         13910.5                 49704.0
# 77224                          8750.2                 39360.4
# 77249                         11559.3                 45813.7
# 77296                         10229.9                 43227.2
# 77341                         10394.4                 42782.3
#
#          Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# subject
# 77191                  6619.9        2764.1        4645.1         1743.9
# 77224                  5428.3        3285.7        4250.9         1699.8
# 77249                  6516.7        2639.8        4018.7         1623.7
# 77296                  6322.7        3524.2        4330.2         1730.7
# 77341                  6130.7        2788.2        3837.7         1547.4
#
#          3rd-Ventricle  4th-Ventricle  ...  SupraTentorialVol  \
# subject                                ...
# 77191           1319.1         1675.6  ...      892903.608990
# 77224           1278.7         1826.7  ...      817036.702441
# 77249           1373.0         1791.5  ...      923401.916970
# 77296           1437.0         1621.0  ...      888153.732643
# 77341           1063.7         1315.9  ...      901145.144019
#
#          SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  MaskVol  \
# subject
# 77191               862323.608990                       861261  1350018
# 77224               797108.702441                       796089  1157558
# 77249               899988.916970                       898152  1301466
# 77296               862320.732643                       861303  1261011
# 77341               886984.144019                       885613  1244896
#
#          BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles  \
# subject
# 77191               0.671630         0.888362              17               7
# 77224               0.700176         0.888274              27              30
# 77249               0.740078         0.927102              14              14
# 77296               0.706605         0.896072              24              38
# 77341               0.728111         0.901856              17              21
#
#          SurfaceHoles  EstimatedTotalIntraCranialVol
# subject
# 77191              24                   1.519672e+06
# 77224              57                   1.303155e+06
# 77249              28                   1.403800e+06
# 77296              62                   1.407266e+06
# 77341              38                   1.380371e+06
#
# [5 rows x 66 columns]

# %%
statsFastS = statsFastS.reindex(sorted(statsFastS.columns), axis=1)

# %%
statsFastS.describe()
# Out:
#        3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count     391.000000     391.000000          391.0    391.000000
# mean     1369.234783    1895.917647            0.0  20949.216880
# std       478.733565     473.634846            0.0   2203.918287
# min       542.200000     731.600000            0.0  15581.500000
# 25%      1019.400000    1553.250000            0.0  19507.550000
# 50%      1271.400000    1810.100000            0.0  20820.100000
# 75%      1649.450000    2136.000000            0.0  22493.350000
# max      3544.300000    3768.100000            0.0  27782.100000
#
#         BrainSegVol  BrainSegVol-to-eTIV  BrainSegVolNotVent  \
# count  3.910000e+02           391.000000        3.910000e+02
# mean   1.072269e+06             0.726004        1.043221e+06
# std    1.037948e+05             0.026561        9.904662e+04
# min    8.400910e+05             0.661940        8.173580e+05
# 25%    9.992830e+05             0.710196        9.715210e+05
# 50%    1.069028e+06             0.723749        1.041135e+06
# 75%    1.141720e+06             0.740565        1.111820e+06
# max    1.387998e+06             0.911184        1.307269e+06
#
#        BrainSegVolNotVentSurf  CC_Anterior   CC_Central  ...  SurfaceHoles  \
# count            3.910000e+02   391.000000   391.000000  ...    391.000000
# mean             1.043585e+06   918.318926   626.058568  ...     49.521739
# std              9.909316e+04   167.297810   158.863589  ...     35.230798
# min              8.173956e+05   454.100000   269.500000  ...     12.000000
# 25%              9.720620e+05   805.800000   498.150000  ...     30.000000
# 50%              1.041253e+06   911.800000   628.500000  ...     42.000000
# 75%              1.112186e+06  1016.400000   745.350000  ...     57.500000
# max              1.308019e+06  1385.600000  1149.200000  ...    356.000000
#
#         TotalGrayVol  WM-hypointensities  lhCerebralWhiteMatterVol  \
# count     391.000000          391.000000                391.000000
# mean   587636.226003         2482.513555             216035.931653
# std     49637.388634         2693.581906              25755.318579
# min    470458.847313          685.200000             153163.715313
# 25%    552814.760273         1340.900000             196360.423314
# 50%    587564.484320         1699.200000             214391.321402
# 75%    619854.672622         2630.150000             233953.781299
# max    733674.426033        26763.000000             282353.513531
#
#          lhCortexVol  lhSurfaceHoles  non-WM-hypointensities  \
# count     391.000000      391.000000                   391.0
# mean   218996.653107       24.421995                     0.0
# std     19771.941679       17.760181                     0.0
# min    173294.575857        3.000000                     0.0
# 25%    204962.156559       14.000000                     0.0
# 50%    217469.514099       20.000000                     0.0
# 75%    231954.474538       28.500000                     0.0
# max    282725.569089      179.000000                     0.0
#
#        rhCerebralWhiteMatterVol    rhCortexVol  rhSurfaceHoles
# count                391.000000     391.000000      391.000000
# mean              215954.530729  219296.002564       25.099744
# std                25598.015080   19671.707826       19.189548
# min               153744.072130  165726.271456        3.000000
# 25%               197932.076791  205164.027353       15.000000
# 50%               215416.673620  218711.163010       21.000000
# 75%               234150.805652  231628.215223       29.000000
# max               276971.491337  282556.856944      177.000000
#
# [8 rows x 66 columns]

# %%
#Dimensiones de la base de datos
print(statsFastS.shape)
# Out:
# (391, 66)

# %%
# El número total de valores únicos por características
print(statsFastS.nunique())
# Out:
# 3rd-Ventricle               386
# 4th-Ventricle               388
# 5th-Ventricle                 1
# Brain-Stem                  389
# BrainSegVol                 391
#                            ...
# lhSurfaceHoles               66
# non-WM-hypointensities        1
# rhCerebralWhiteMatterVol    391
# rhCortexVol                 391
# rhSurfaceHoles               62
# Length: 66, dtype: int64

# %%
# Histogramas
for i in range(0,68,4):
    statsFastS.iloc[:,i:i+4].hist(figsize=(10, 15), bins=70, xlabelsize=8, ylabelsize=8);
    plt.show()

# %%
# Valores perdidos (missing values)
statsFastS.isnull().values.any()
# Out:
# False

# %%
# Identificación de valores anómalos (Outliers)
col_name=list(statsFastS.columns) 
print(col_name)

for i in range(0,68,4):
    boxplot = statsFastS.iloc[:,i:i+4].boxplot(grid=True, rot=60, fontsize=8)
    plt.show()
# Out:
# ['3rd-Ventricle', '4th-Ventricle', '5th-Ventricle', 'Brain-Stem', 'BrainSegVol', 'BrainSegVol-to-eTIV', 'BrainSegVolNotVent', 'BrainSegVolNotVentSurf', 'CC_Anterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Mid_Posterior', 'CC_Posterior', 'CSF', 'CerebralWhiteMatterVol', 'CortexVol', 'EstimatedTotalIntraCranialVol', 'Left-Accumbens-area', 'Left-Amygdala', 'Left-Caudate', 'Left-Cerebellum-Cortex', 'Left-Cerebellum-White-Matter', 'Left-Hippocampus', 'Left-Inf-Lat-Vent', 'Left-Lateral-Ventricle', 'Left-Pallidum', 'Left-Putamen', 'Left-Thalamus-Proper', 'Left-VentralDC', 'Left-WM-hypointensities', 'Left-choroid-plexus', 'Left-non-WM-hypointensities', 'Left-vessel', 'MaskVol', 'MaskVol-to-eTIV', 'Optic-Chiasm', 'Right-Accumbens-area', 'Right-Amygdala', 'Right-Caudate', 'Right-Cerebellum-Cortex', 'Right-Cerebellum-White-Matter', 'Right-Hippocampus', 'Right-Inf-Lat-Vent', 'Right-Lateral-Ventricle', 'Right-Pallidum', 'Right-Putamen', 'Right-Thalamus-Proper', 'Right-VentralDC', 'Right-WM-hypointensities', 'Right-choroid-plexus', 'Right-non-WM-hypointensities', 'Right-vessel', 'SubCortGrayVol', 'SupraTentorialVol', 'SupraTentorialVolNotVent', 'SupraTentorialVolNotVentVox', 'SurfaceHoles', 'TotalGrayVol', 'WM-hypointensities', 'lhCerebralWhiteMatterVol', 'lhCortexVol', 'lhSurfaceHoles', 'non-WM-hypointensities', 'rhCerebralWhiteMatterVol', 'rhCortexVol', 'rhSurfaceHoles']

# %%
statsFastS.iloc[:,:34].plot(kind='box',subplots=True, layout=(9,4), sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %%
statsFastS.iloc[:,34:68].plot(kind='box',subplots=True, layout=(9,4), sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %%
f, ax = plt.subplots(figsize=(50, 50))
corr = statsFastS.corr()
sns.heatmap(corr,annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
statsFastS.iloc[30:60]
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10259           1398.9         1316.0              0     22583.4      1055298
# 10286           1405.2         1885.6              0     21017.4      1012894
# 10316           1447.7         1738.1              0     21097.3      1164258
# 10319           2526.8         2050.5              0     21746.9      1186562
# 10329           1188.9         1589.7              0     20161.3       979059
# 10338           2347.9         2989.7              0     22079.5      1135974
# 10361           1844.3         1440.6              0     19208.6      1076295
# 10367           1740.9         1702.2              0     20578.1      1248584
# 10384           1084.5         1448.3              0     20568.1      1028712
# 10388           1189.6         1717.5              0     22276.9      1072256
# 10398           1122.7         1878.6              0     20786.8       990972
# 10407           1745.4         2681.5              0     21180.9      1065667
# 10416           1055.1         1355.1              0     19319.9      1101943
# 10420           1306.5         1674.8              0     19727.4      1015520
# 10424            875.9         1676.2              0     19222.6       917817
# 10426           2066.4         1838.8              0     20461.9      1044570
# 10448           1304.8         1185.6              0     22494.1      1188995
# 10453            868.8         1454.7              0     21494.1      1216590
# 10493           1270.0         2315.6              0     19863.5      1253090
# 10511            864.9         1189.1              0     17888.0       871883
# 10515            832.8         1977.2              0     19979.1       983636
# 10540            779.7         2036.5              0     25121.9      1240176
# 10541           1171.9         2563.7              0     24888.9      1247532
# 10560           1261.4         1522.9              0     20346.6      1004687
# 10583           1200.4         2485.8              0     20458.2      1059564
# 10600           1875.4         2365.5              0     21885.9      1099299
# 10601           1884.3         2637.5              0     22851.2      1181919
# 10627            756.5         1686.5              0     21323.6      1142527
# 10649           1222.3         1409.9              0     19571.3      1057246
# 10651           3038.3         2220.8              0     20023.9      1169605
#
#          BrainSegVol-to-eTIV  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10259               0.733833             1029434            1.029664e+06
# 10286               0.700778              988366            9.888782e+05
# 10316               0.741277             1139958            1.139782e+06
# 10319               0.695966             1142483            1.142352e+06
# 10329               0.698513              948986            9.491777e+05
# 10338               0.696624             1084333            1.085132e+06
# 10361               0.691108             1043240            1.043176e+06
# 10367               0.695081             1217671            1.217332e+06
# 10384               0.751830             1010007            1.010673e+06
# 10388               0.733591             1045278            1.045881e+06
# 10398               0.713738              966290            9.665860e+05
# 10407               0.706542             1031699            1.031323e+06
# 10416               0.720648             1059376            1.059663e+06
# 10420               0.785941              994491            9.952442e+05
# 10424               0.734027              900668            9.011901e+05
# 10426               0.705564              999748            1.000399e+06
# 10448               0.694934             1172179            1.172210e+06
# 10453               0.736860             1182257            1.182060e+06
# 10493               0.738292             1223466            1.223896e+06
# 10511               0.756299              843126            8.435656e+05
# 10515               0.787745              967967            9.682066e+05
# 10540               0.714533             1220547            1.221383e+06
# 10541               0.726335             1216256            1.216841e+06
# 10560               0.716884              972610            9.727605e+05
# 10583               0.746120             1031053            1.031207e+06
# 10600               0.713829             1046432            1.046633e+06
# 10601               0.698337             1126274            1.126541e+06
# 10627               0.724940             1112546            1.112873e+06
# 10649               0.765216             1036919            1.037360e+06
# 10651               0.710601             1116347            1.116334e+06
#
#          CC_Anterior  CC_Central  ...  SurfaceHoles   TotalGrayVol  \
# subject                           ...
# 10259          927.8       660.1  ...            46  593347.140827
# 10286          499.6       601.6  ...            23  555121.594106
# 10316          789.0       984.8  ...            27  621092.191247
# 10319          714.0       425.7  ...            47  675560.556807
# 10329          818.7       498.6  ...            58  562209.973706
# 10338         1112.0       624.4  ...            22  575727.405514
# 10361          995.6       683.0  ...           167  598207.760651
# 10367         1193.5       809.2  ...            26  666594.859418
# 10384          866.2       730.3  ...            29  563292.349053
# 10388          920.0       456.1  ...            52  599978.404310
# 10398         1067.3       728.4  ...            14  536552.312818
# 10407          897.8       666.2  ...            17  562151.290917
# 10416         1193.7       745.0  ...            71  599772.698820
# 10420          890.5       576.1  ...            62  605256.684246
# 10424          753.9       731.1  ...            23  500819.783625
# 10426          996.5       465.7  ...            33  554569.891589
# 10448          671.6       535.4  ...            50  658749.628339
# 10453         1312.9       933.8  ...            21  656379.742620
# 10493         1226.5       717.2  ...            44  681210.714684
# 10511          986.2       670.7  ...            17  502773.532853
# 10515          701.9       427.6  ...            38  564106.301934
# 10540          889.8       790.5  ...            31  656571.201214
# 10541         1104.8       711.7  ...            22  680593.846589
# 10560          938.5       578.3  ...            40  545765.368358
# 10583         1131.8       827.4  ...            33  587920.047715
# 10600         1120.9       458.6  ...            52  566714.526333
# 10601          947.3       441.2  ...            42  632614.708934
# 10627         1330.3       652.6  ...            51  600824.101705
# 10649          691.9       814.8  ...            17  564737.521461
# 10651         1108.1       461.2  ...           103  635281.604547
#
#          WM-hypointensities  lhCerebralWhiteMatterVol    lhCortexVol  \
# subject
# 10259                1695.5             204136.096363  218224.604648
# 10286                1101.0             200583.794435  206838.720718
# 10316                2701.5             244118.054477  231948.961687
# 10319                2044.1             221523.806340  254865.266366
# 10329                1349.8             181924.897731  205940.593536
# 10338                3465.1             243461.463673  211944.108943
# 10361                2590.7             210280.655739  224589.379756
# 10367                2428.4             262354.764781  247335.060481
# 10384                1023.1             211925.671038  205822.183754
# 10388                5962.6             209723.904607  218454.859335
# 10398                1630.3             203319.929666  198793.998494
# 10407                1275.7             223849.452980  206605.529639
# 10416                5381.3             219080.727995  227456.202418
# 10420                1103.6             183026.657858  229298.903225
# 10424                1078.8             188214.246014  181260.260520
# 10426                1977.0             212126.631447  207037.700804
# 10448                1673.4             243326.197287  248749.308477
# 10453                1331.2             248581.616360  254116.170366
# 10493                1668.3             259470.768548  262574.154721
# 10511                1227.6             158383.842787  178909.045266
# 10515                1303.8             189688.412172  207531.031440
# 10540                1492.1             268293.902849  243651.432446
# 10541                1140.3             254093.318383  253749.143837
# 10560                2140.9             202747.551866  202340.897015
# 10583                1651.2             210794.158624  216108.383142
# 10600                1686.6             227482.789396  206136.702359
# 10601                2782.6             235741.656782  238495.443694
# 10627                2412.7             242318.317810  227790.029671
# 10649                1435.7             225738.409539  217980.069686
# 10651                4302.0             229147.483195  243580.953630
#
#          lhSurfaceHoles  non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject
# 10259                21                       0             205374.267100
# 10286                14                       0             207684.803073
# 10316                 6                       0             246068.316173
# 10319                22                       0             221619.518036
# 10329                28                       0             184219.799282
# 10338                14                       0             241678.355697
# 10361                78                       0             211962.785088
# 10367                17                       0             262112.541219
# 10384                12                       0             209180.922105
# 10388                36                       0             209624.934983
# 10398                 7                       0             201692.751930
# 10407                 9                       0             220893.694453
# 10416                24                       0             217809.269915
# 10420                32                       0             181546.848105
# 10424                 9                       0             191163.097611
# 10426                15                       0             213375.127286
# 10448                27                       0             244308.358696
# 10453                13                       0             248205.068859
# 10493                21                       0             257399.963679
# 10511                 7                       0             159064.194250
# 10515                18                       0             190716.861026
# 10540                17                       0             268791.903094
# 10541                13                       0             250034.574385
# 10560                20                       0             202491.603298
# 10583                16                       0             208603.443515
# 10600                25                       0             225913.812996
# 10601                23                       0             232702.917650
# 10627                39                       0             244940.163830
# 10649                 7                       0             224311.918487
# 10651                51                       0             231791.799177
#
#            rhCortexVol  rhSurfaceHoles
# subject
# 10259    220690.536179              25
# 10286    210396.873388               9
# 10316    225068.229560              21
# 10319    257078.290441              25
# 10329    208116.380170              30
# 10338    215632.296572               8
# 10361    227043.380894              89
# 10367    250225.798937               9
# 10384    202696.165299              17
# 10388    219140.544975              16
# 10398    197725.314324               7
# 10407    206788.761278               8
# 10416    226754.496402              47
# 10420    222963.781021              30
# 10424    183864.523105              14
# 10426    210472.190786              18
# 10448    250657.319862              23
# 10453    253538.572253               8
# 10493    258237.559963              23
# 10511    181673.487587              10
# 10515    207247.270494              20
# 10540    243314.768767              14
# 10541    248606.702753               9
# 10560    201533.471343              20
# 10583    216644.664574              17
# 10600    202842.823974              27
# 10601    238123.265240              19
# 10627    229833.072033              12
# 10649    212097.451775              10
# 10651    241970.650917              52
#
# [30 rows x 66 columns]

# %% [markdown]
# ## Describing FreeSurfer subjects stats

# %%
stats_f6 = pd.read_excel('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/ALFA_PLUS_freesurfer6_hires.xlsx')

# %%
stats_f6.head()
# Out:
#               ID measurement             region   value  subject
# 0  BBRC02_E00014   normRange        CC_Anterior   111.0    10994
# 1  BBRC02_E00014     NVoxels      Right-Caudate  7154.0    10994
# 2  BBRC02_E00014     NVoxels      Right-Putamen  9687.0    10994
# 3  BBRC02_E00014     NVoxels     Right-Pallidum  4189.0    10994
# 4  BBRC02_E00014     NVoxels  Right-Hippocampus  9832.0    10994

# %%
stats_f6.set_index('subject', inplace= True)

# %%
stats_f6.sort_index(inplace=True)

# %%
stats_f6.head()
# Out:
#                   ID measurement            region  value
# subject
# 10019    BBRC_E00046     NVoxels      Right-vessel   70.0
# 10019    BBRC_E00046   normRange   CC_Mid_Anterior   92.0
# 10019    BBRC_E00046   normRange        CC_Central   98.0
# 10019    BBRC_E00046   normRange  CC_Mid_Posterior  119.0
# 10019    BBRC_E00046   normRange      CC_Posterior   84.0

# %%
stats_f6vol = stats_f6[stats_f6['measurement'] == 'Volume_mm3']

# %%
stats_f6vol.head()
# Out:
#                   ID measurement              region   value
# subject
# 10019    BBRC_E00046  Volume_mm3  WM-hypointensities  2255.2
# 10019    BBRC_E00046  Volume_mm3         CC_Anterior   644.2
# 10019    BBRC_E00046  Volume_mm3     CC_Mid_Anterior   263.1
# 10019    BBRC_E00046  Volume_mm3          CC_Central   297.6
# 10019    BBRC_E00046  Volume_mm3    CC_Mid_Posterior   279.5

# %%
statsFreeS = stats_f6vol.pivot_table(values='value', index=stats_f6vol.index, columns='region', aggfunc='first')

# %%
statsFreeS.shape
# Out:
# (369, 61)

# %%
statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10019           2280.7         2919.5            0.0     22887.2    2856756.0
# 10026           1948.6         2111.0            0.0     18946.6    2597310.0
# 10032            901.5         1122.1            0.0     20236.2    2765359.0
# 10034            911.4         1793.3            0.0     18160.1    2535035.0
# 10036           2221.8         2651.8            0.0     18583.1    2496475.0
#
# region   BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  CC_Central  \
# subject
# 10019             2787249.0            1.355871e+06        644.2       297.6
# 10026             2478538.0            1.145995e+06        687.2       312.0
# 10032             2719238.0            1.313665e+06        784.8       450.8
# 10034             2486229.0            1.208712e+06        637.1       321.9
# 10036             2375627.0            1.125398e+06        680.4       263.3
#
# region   CC_Mid_Anterior  ...  SupraTentorialVolNotVentVox   TotalGrayVol  \
# subject                   ...
# 10019              263.1  ...                    2443176.0  917430.755886
# 10026              319.0  ...                    2214913.0  803245.479697
# 10032              576.8  ...                    2407752.0  832110.653475
# 10034              434.3  ...                    2185913.0  794951.680058
# 10036              297.5  ...                    2072429.0  799317.555004
#
# region   VentricleChoroidVol  WM-hypointensities          eTIV  \
# subject
# 10019                54608.0              2255.2  1.681487e+06
# 10026               105997.0              2676.0  1.609609e+06
# 10032                39827.0              1108.5  1.601433e+06
# 10034                40853.0              1503.0  1.424579e+06
# 10036               107335.0              2254.7  1.486648e+06
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10019               184987.886487  253325.708521                     0.0
# 10026               145415.615155  240024.341842                     2.1
# 10032               202966.023257  225312.386550                     1.1
# 10034               177036.945915  217284.396436                     0.0
# 10036               130448.401138  218025.842275                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10019               184713.447646  253772.047365
# 10026               142811.135281  234869.137855
# 10032               210975.503634  234558.266925
# 10034               177396.179170  214724.283622
# 10036               135421.189927  217877.712730
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Comparing FastSurfer vs FreeSurfer dataframe

# %%
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 66)
# (369, 61)

# %%
statsFastS.head()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10013           1961.1         1873.5              0     21146.6      1076960
# 10013           1939.1         1849.9              0     21262.4      1084001
# 10019           2335.3         3003.2              0     22947.8      1206855
# 10026           2017.8         2357.3              0     20385.5      1110897
# 10032           1020.2         1350.3              0     21828.4      1204293
#
#          BrainSegVol-to-eTIV  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10013               0.708702             1040879            1.041253e+06
# 10013               0.715196             1048161            1.048799e+06
# 10019               0.716136             1175093            1.175647e+06
# 10026               0.697698             1059210            1.059082e+06
# 10032               0.735471             1183601            1.184661e+06
#
#          CC_Anterior  CC_Central  ...  SurfaceHoles   TotalGrayVol  \
# subject                           ...
# 10013         1064.3       695.4  ...            44  592711.111666
# 10013          968.0       454.7  ...            70  592865.003380
# 10019          928.5       667.8  ...            45  667488.665351
# 10026          950.0       450.6  ...            52  606974.728489
# 10032         1060.9       914.8  ...            23  623645.895177
#
#          WM-hypointensities  lhCerebralWhiteMatterVol    lhCortexVol  \
# subject
# 10013                2799.6             211591.434475  221637.861596
# 10013                2948.9             215193.292623  224053.188198
# 10019                1927.9             241968.281419  251468.157656
# 10026                2325.5             214797.860888  238147.069588
# 10032                 894.3             263883.923522  233179.819260
#
#          lhSurfaceHoles  non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject
# 10013                21                       0             209867.261886
# 10013                46                       0             213985.656464
# 10019                28                       0             241150.947036
# 10026                23                       0             215416.673620
# 10032                11                       0             269911.449888
#
#            rhCortexVol  rhSurfaceHoles
# subject
# 10013    224159.250070              23
# 10013    221333.815182              24
# 10019    249285.507695              17
# 10026    236342.658901              29
# 10032    235479.075916              12
#
# [5 rows x 66 columns]

# %%
statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10019           2280.7         2919.5            0.0     22887.2    2856756.0
# 10026           1948.6         2111.0            0.0     18946.6    2597310.0
# 10032            901.5         1122.1            0.0     20236.2    2765359.0
# 10034            911.4         1793.3            0.0     18160.1    2535035.0
# 10036           2221.8         2651.8            0.0     18583.1    2496475.0
#
# region   BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  CC_Central  \
# subject
# 10019             2787249.0            1.355871e+06        644.2       297.6
# 10026             2478538.0            1.145995e+06        687.2       312.0
# 10032             2719238.0            1.313665e+06        784.8       450.8
# 10034             2486229.0            1.208712e+06        637.1       321.9
# 10036             2375627.0            1.125398e+06        680.4       263.3
#
# region   CC_Mid_Anterior  ...  SupraTentorialVolNotVentVox   TotalGrayVol  \
# subject                   ...
# 10019              263.1  ...                    2443176.0  917430.755886
# 10026              319.0  ...                    2214913.0  803245.479697
# 10032              576.8  ...                    2407752.0  832110.653475
# 10034              434.3  ...                    2185913.0  794951.680058
# 10036              297.5  ...                    2072429.0  799317.555004
#
# region   VentricleChoroidVol  WM-hypointensities          eTIV  \
# subject
# 10019                54608.0              2255.2  1.681487e+06
# 10026               105997.0              2676.0  1.609609e+06
# 10032                39827.0              1108.5  1.601433e+06
# 10034                40853.0              1503.0  1.424579e+06
# 10036               107335.0              2254.7  1.486648e+06
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10019               184987.886487  253325.708521                     0.0
# 10026               145415.615155  240024.341842                     2.1
# 10032               202966.023257  225312.386550                     1.1
# 10034               177036.945915  217284.396436                     0.0
# 10036               130448.401138  218025.842275                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10019               184713.447646  253772.047365
# 10026               142811.135281  234869.137855
# 10032               210975.503634  234558.266925
# 10034               177396.179170  214724.283622
# 10036               135421.189927  217877.712730
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Comprobación de filas y columnas comunes

# %%
column_notFastS = []
for column in statsFastS.columns:
    if column not in statsFreeS.columns:
        print(column)
        column_notFastS.append(column)
    else:
        continue
statsFastS.drop(column_notFastS,axis=1, inplace=True)
# Out:
# BrainSegVol-to-eTIV
# CortexVol
# EstimatedTotalIntraCranialVol
# MaskVol-to-eTIV
# SurfaceHoles
# lhSurfaceHoles
# rhSurfaceHoles

# %%
column_notFreeS = []
for column in statsFreeS.columns:
    if column not in statsFastS.columns:
        print(column)
        column_notFreeS.append(column)
    else:
        continue
statsFreeS.drop(column_notFreeS,axis=1, inplace=True)
# Out:
# VentricleChoroidVol
# eTIV

# %%
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 59)
# (369, 59)

# %%
indexFreeS = []
for index, row in statsFreeS.iterrows():
    indexFreeS.append(index)
#print(indexFreeS)
indexFastS = []
for index, row in statsFastS.iterrows():
    indexFastS.append(index)
    
print(len(indexFastS))
print(len(indexFreeS))
print(indexFastS[2])
# Out:
# 391
# 369
# 10019

# %%
index_not = []
for i in range(len(indexFastS)):
    if indexFastS[i] not in indexFreeS:
        print(indexFastS[i])
        index_not.append(indexFastS[i])
        #statsFastS.drop(indexFastS[i], inplace=True)

    else:
        continue
statsFastS.drop(index_not, inplace=True)
# Out:
# 10013
# 10013
# 10651
# 10651
# 11309
# 11309
# 11491
# 11491
# 11872
# 11872
# 13135
# 13135
# 55395
# 55395
# 66020
# 66020
# 77072
# 77072

# %%
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (373, 59)
# (369, 59)

# %%
statsFastS.tail()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 77191           1319.1         1675.6              0     20424.5      1020657
# 77224           1278.7         1826.7              0     16543.2       912437
# 77249           1373.0         1791.5              0     19355.5      1038921
# 77296           1437.0         1621.0              0     17797.5       994381
# 77341           1063.7         1315.9              0     19506.2      1005063
#
#          BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  CC_Central  \
# subject
# 77191                985570            9.857496e+05        805.1       398.6
# 77224                888034            8.883267e+05        706.1       368.5
# 77249               1011457            1.012343e+06        804.1       417.5
# 77296                964162            9.641267e+05        668.1       366.6
# 77341                987595            9.882401e+05        649.4       483.0
#
#          CC_Mid_Anterior  ...  SupraTentorialVol  SupraTentorialVolNotVent  \
# subject                   ...
# 77191              382.3  ...      892903.608990             862323.608990
# 77224              351.2  ...      817036.702441             797108.702441
# 77249              342.7  ...      923401.916970             899988.916970
# 77296              353.7  ...      888153.732643             862320.732643
# 77341              536.6  ...      901145.144019             886984.144019
#
#          SupraTentorialVolNotVentVox   TotalGrayVol  WM-hypointensities  \
# subject
# 77191                         861261  558671.120653              3188.9
# 77224                         796089  513407.766771              2211.5
# 77249                         898152  576782.720428              1769.2
# 77296                         861303  560421.715534              1569.6
# 77341                         885613  563234.478010              1160.5
#
#          lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 77191               199091.934974  204458.743485                       0
# 77224               180125.011790  195680.995152                       0
# 77249               207613.372213  219174.109984                       0
# 77296               192348.292639  210009.340794                       0
# 77341               201078.908012  215212.544379                       0
#
#          rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 77191               201590.553363  205900.377168
# 77224               178720.923880  196351.771619
# 77249               205605.824330  217188.610443
# 77296               193086.724470  216424.374740
# 77341               204535.757997  218820.933631
#
# [5 rows x 59 columns]

# %%
statsFreeS.tail()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 77191           1342.3         1495.3            0.0     19791.3    2391306.0
# 77224           1258.8         1461.9            0.0     15874.7    2164425.0
# 77249           1335.2         1603.2            0.0     18947.9    2424586.0
# 77296           1329.9         1338.7            0.0     17119.3    2329576.0
# 77341            959.2         1208.6            0.0     18714.9    2360309.0
#
# region   BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  CC_Central  \
# subject
# 77191             2312154.0            1.125425e+06        598.9       303.0
# 77224             2116620.0            1.021407e+06        527.9       290.8
# 77249             2362735.0            1.137596e+06        583.2       261.7
# 77296             2265217.0            1.086239e+06        538.7       281.1
# 77341             2324750.0            1.126227e+06        500.4       355.6
#
# region   CC_Mid_Anterior  ...  SupraTentorialVol  SupraTentorialVolNotVent  \
# subject                   ...
# 77191              294.8  ...      864861.343801             795601.343801
# 77224              274.9  ...      798887.450698             760010.450698
# 77249              261.0  ...      893830.953047             840744.953047
# 77296              265.3  ...      859725.935811             804040.935811
# 77341              386.9  ...      874161.997539             845328.997539
#
# region   SupraTentorialVolNotVentVox   TotalGrayVol  WM-hypointensities  \
# subject
# 77191                      1996031.0  775699.315909              3151.7
# 77224                      1869847.0  706438.009013              2822.9
# 77249                      2082442.0  771690.015510              2148.5
# 77296                      1998615.0  759110.593038              1822.1
# 77341                      2062682.0  754849.477600              1034.4
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 77191               139075.726663  204760.689824                     0.0
# 77224               131354.005067  198909.777501                     0.4
# 77249               154238.338948  218245.193294                     0.0
# 77296               135971.741052  210512.790672                     0.0
# 77341               154966.697014  217085.143686                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 77191               142418.301229  203632.626085
# 77224               134106.436618  197757.231512
# 77249               157246.598589  213138.822216
# 77296               137623.601722  215319.802365
# 77341               159875.822924  218419.333914
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Posicion en la que aparecen repetidos los índices en las stats de FastSurfer

# %%
lista = statsFastS.index.duplicated().tolist()
for i in [i for i,x in enumerate(lista) if x == 1]:
    print(i)
# Out:
# 83
# 161
# 206
# 285
