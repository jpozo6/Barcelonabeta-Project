# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import os

# %% [markdown]
# # 1. Describing FastSurfer subjects stats

# %% [markdown]
# ### Creation of DataFrame with FastSurfer stats (ALFA_PLUS subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_PLUS subjects

statsFastS = pd.read_csv('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/aseg_stats.csv')

# %%
#first 5 rows of DataFrame

statsFastS.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0               0                 15027.1              641.9
# 1               1                 15028.7              809.5
# 2               2                 10931.6              760.5
# 3               3                 21022.3              886.6
# 4               4                  7773.4              533.2
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       14518.4                 49024.5                5880.1
# 1                       14101.8                 49310.6                6153.4
# 2                       13588.4                 56167.5                7061.4
# 3                       11670.9                 40964.6                6156.1
# 4                       14658.8                 49447.8                7429.0
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# ...

# %%
scans = []

for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/Archivos_ALFAPLUS_security_copy'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        scans.append(int(filename.split("_")[2]))
print(scans)
# Out:
# [1401, 301, 301, 201, 1201, 401, 401, 401, 401, 401, 401, 301, 301, 301, 301, 401, 401, 401, 301, 301, 1401, 301, 401, 301, 401, 401, 1401, 401, 301, 301, 301, 201, 201, 301, 401, 201, 301, 1401, 401, 201, 201, 201, 401, 401, 401, 401, 1401, 201, 201, 301, 401, 301, 201, 401, 401, 301, 301, 401, 401, 1401, 401, 301, 401, 301, 301, 201, 301, 901, 201, 301, 901, 401, 201, 301, 1401, 201, 401, 1401, 201, 301, 401, 301, 401, 301, 201, 1101, 301, 401, 201, 401, 301, 401, 1901, 301, 401, 401, 301, 401, 301, 401, 501, 301, 501, 301, 201, 401, 201, 301, 301, 301, 201, 201, 201, 201, 401, 401, 901, 301, 301, 401, 201, 1401, 401, 401, 501, 401, 401, 201, 401, 301, 401, 301, 301, 401, 401, 1501, 401, 201, 1601, 301, 301, 901, 201, 301, 201, 401, 401, 901, 1401, 301, 301, 201, 401, 201, 301, 401, 401, 301, 401, 301, 401, 301, 301, 301, 301, 301, 301, 401, 201, 301, 1501, 401, 1401, 401, 401, 401, 401, 201, 301, 401, 501, 301, 301, 301, 401, 401, 401, 401, 1601, 301, 201, 401, 301, 401, 301, 401,
# ...

# %% [markdown]
# ### Creation of DataFrame with FastSurfer stats (ALFA_OPCIONAL subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_OPCIONAL subjects

statsFastS_AO = pd.read_csv('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/stats_ALFA_OPCIONAL.csv')

# %%
#first 5 rows of DataFrame

statsFastS_AO.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0               0                 10682.6              502.0
# 1               1                  8106.8              456.0
# 2               2                 12982.6              704.8
# 3               3                 11437.9              841.0
# 4               4                  5106.4              768.9
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       16251.3                 55801.7                7752.9
# 1                       11804.6                 47019.3                6500.4
# 2                       12580.7                 45940.6                6759.9
# 3                       11674.1                 53769.6                5649.2
# 4                       14600.3                 54463.1                6753.7
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# ...

# %% [markdown]
# ### Replacing column name (Measure:volume >> subject), modifying his values and setting 'subject' as index

# %% [markdown]
# #### ALFA_PLUS

# %%
#renaming values of Measure:volume column

names = []
scans = []
for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/Archivos_ALFAPLUS_security_copy'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        names.append(int(filename[0:5]))
        scans.append(int(filename.split("_")[2]))
for i in range(0,statsFastS.shape[0]):
    statsFastS["Measure:volume"].replace({i: names[i]}, inplace=True)

#statsFastS['Scan'] = scans    
#rename column    
statsFastS.rename(columns={'Measure:volume': 'subject'}, inplace=True)

#set subject as index
statsFastS.set_index('subject', inplace= True)

statsFastS.head()
# Out:
#          Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# subject
# 10013                   15027.1              641.9
# 10013                   15028.7              809.5
# 10019                   10931.6              760.5
# 10026                   21022.3              886.6
# 10032                    7773.4              533.2
#
#          Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# subject
# 10013                         14518.4                 49024.5
# 10013                         14101.8                 49310.6
# 10019                         13588.4                 56167.5
# 10026                         11670.9                 40964.6
# 10032                         14658.8                 49447.8
#
#          Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# subject
# 10013                  5880.1        3105.0        5069.1         1769.0
# 10013                  6153.4        3034.4        4836.5         1647.6
# ...

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#renaming values of Measure:volume column

names = []
#scans = []
for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/ALFA_OPCIONAL_security'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        names.append(int(filename[0:5]))
        #scans.append(int(filename.split("_")[2]))
for i in range(0,statsFastS_AO.shape[0]):
    statsFastS_AO["Measure:volume"].replace({i: names[i]}, inplace=True)

#statsFastS['Scan'] = scans    
#rename column    
statsFastS_AO.rename(columns={'Measure:volume': 'subject'}, inplace=True)

#set subject as index
statsFastS_AO.set_index('subject', inplace= True)

statsFastS_AO.head()
# Out:
#          Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# subject
# 10010                   10682.6              502.0
# 10011                    8106.8              456.0
# 10012                   12982.6              704.8
# 10014                   11437.9              841.0
# 10016                    5106.4              768.9
#
#          Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# subject
# 10010                         16251.3                 55801.7
# 10011                         11804.6                 47019.3
# 10012                         12580.7                 45940.6
# 10014                         11674.1                 53769.6
# 10016                         14600.3                 54463.1
#
#          Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# subject
# 10010                  7752.9        3020.4        5141.0         2082.6
# 10011                  6500.4        2819.2        4847.4         1631.5
# ...

# %% [markdown]
# ### Sorting column names alphabetically

# %% [markdown]
# #### ALFA_PLUS

# %%
#sort column names
statsFastS = statsFastS.reindex(sorted(statsFastS.columns), axis=1)

statsFastS.describe()
# Out:
#        3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count     391.000000     391.000000          391.0    391.000000
# mean     1369.234783    1895.917647            0.0  20949.216880
# std       478.733565     473.634846            0.0   2203.918287
# min       542.200000     731.600000            0.0  15581.500000
# 25%      1019.400000    1553.250000            0.0  19507.550000
# 50%      1271.400000    1810.100000            0.0  20820.100000
# 75%      1649.450000    2136.000000            0.0  22493.350000
# max      3544.300000    3768.100000            0.0  27782.100000
#
#         BrainSegVol  BrainSegVol-to-eTIV  BrainSegVolNotVent  \
# count  3.910000e+02           391.000000        3.910000e+02
# mean   1.072269e+06             0.726004        1.043221e+06
# std    1.037948e+05             0.026561        9.904662e+04
# min    8.400910e+05             0.661940        8.173580e+05
# 25%    9.992830e+05             0.710196        9.715210e+05
# ...

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#sort column names
statsFastS_AO = statsFastS_AO.reindex(sorted(statsFastS_AO.columns), axis=1)

statsFastS_AO.describe()
# Out:
#        3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count    1184.000000    1184.000000         1184.0   1184.000000
# mean     1329.743919    1904.898818            0.0  20950.567230
# std       477.803566     450.570807            0.0   2197.811505
# min       572.100000     819.700000            0.0  15354.600000
# 25%       981.975000    1585.950000            0.0  19452.400000
# 50%      1230.850000    1833.850000            0.0  20742.300000
# 75%      1560.250000    2160.850000            0.0  22430.775000
# max      4341.000000    5157.900000            0.0  28227.300000
#
#         BrainSegVol  BrainSegVol-to-eTIV  BrainSegVolNotVent  \
# count  1.184000e+03          1184.000000        1.184000e+03
# mean   1.070169e+06             0.724459        1.041260e+06
# std    1.017102e+05             0.030930        9.843763e+04
# min    7.908040e+05             0.605515        7.660560e+05
# 25%    9.954105e+05             0.706312        9.713968e+05
# ...

# %%
#statsFastS['Scan']

# %%
#DataFrame shape
print(statsFastS.shape)
print(statsFastS_AO.shape)
# Out:
# (391, 66)
# (1184, 66)

# %%
# Unique values per column
print(statsFastS.nunique())
# Out:
# 3rd-Ventricle               386
# 4th-Ventricle               388
# 5th-Ventricle                 1
# Brain-Stem                  389
# BrainSegVol                 391
#                            ...
# lhSurfaceHoles               66
# non-WM-hypointensities        1
# rhCerebralWhiteMatterVol    391
# rhCortexVol                 391
# rhSurfaceHoles               62
# Length: 66, dtype: int64

# %%
# Unique values per column
print(statsFastS_AO.nunique())
# Out:
# 3rd-Ventricle               1123
# 4th-Ventricle               1131
# 5th-Ventricle                  1
# Brain-Stem                  1171
# BrainSegVol                 1178
#                             ...
# lhSurfaceHoles               100
# non-WM-hypointensities         1
# rhCerebralWhiteMatterVol    1179
# rhCortexVol                 1179
# rhSurfaceHoles               106
# Length: 66, dtype: int64

# %%
# Missing values
statsFastS.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Correlation map to check if variables are correlated

# %%
#Correlation map
f, ax = plt.subplots(figsize=(50, 50))
corr = statsFastS.corr()
sns.heatmap(corr,annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# # 2. Adapting FastSurfer and FreeSurfer DataFrames

# %% [markdown]
# ### Creation of DataFrame with FreeSurfer stats (ALFA_PLUS subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_PLUS subjects

stats_f6 = pd.read_excel('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/ALFA_PLUS_freesurfer6_hires.xlsx')

# %%
#first 5 rows of DataFrame

stats_f6.head()
# Out:
#               ID measurement             region   value  subject
# 0  BBRC02_E00014   normRange        CC_Anterior   111.0    10994
# 1  BBRC02_E00014     NVoxels      Right-Caudate  7154.0    10994
# 2  BBRC02_E00014     NVoxels      Right-Putamen  9687.0    10994
# 3  BBRC02_E00014     NVoxels     Right-Pallidum  4189.0    10994
# 4  BBRC02_E00014     NVoxels  Right-Hippocampus  9832.0    10994

# %% [markdown]
# ### Creation of DataFrame with FreeSurfer stats (ALFA_OPCIONAL subjects)

# %%
statsFreeS_AO = pd.read_excel('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/bx_freesurfer6hires_ALFA_OPCIONAL_20210506_173302.xlsx')

# %%
statsFreeS_AO.head()
# Out:
#               ID measurement             region       value  subject
# 0  BBRC02_E00002    normMean   Left-Hippocampus     52.7329    13060
# 1  BBRC02_E00002     NVoxels      Right-Putamen  11279.0000    13060
# 2  BBRC02_E00002     NVoxels     Right-Pallidum   4306.0000    13060
# 3  BBRC02_E00002     NVoxels  Right-Hippocampus   8906.0000    13060
# 4  BBRC02_E00002     NVoxels     Right-Amygdala   5028.0000    13060

# %% [markdown]
# ### Setting 'subject' as index and sorting columns alphabetically

# %% [markdown]
# #### ALFA_PLUS

# %%
stats_f6.set_index('subject', inplace= True)
stats_f6.sort_index(inplace=True)

stats_f6.head()
# Out:
#                   ID measurement            region  value
# subject
# 10019    BBRC_E00046     NVoxels      Right-vessel   70.0
# 10019    BBRC_E00046   normRange   CC_Mid_Anterior   92.0
# 10019    BBRC_E00046   normRange        CC_Central   98.0
# 10019    BBRC_E00046   normRange  CC_Mid_Posterior  119.0
# 10019    BBRC_E00046   normRange      CC_Posterior   84.0

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
statsFreeS_AO.set_index('subject', inplace= True)
statsFreeS_AO.sort_index(inplace=True)

statsFreeS_AO.head()
# Out:
#                     ID measurement                       region          value
# subject
# 10010    BBRC02_E07859  Volume_mm3                  lhCortexVol  223535.737235
# 10010    BBRC02_E07859   normRange  Left-non-WM-hypointensities       0.000000
# 10010    BBRC02_E07859   normRange       non-WM-hypointensities       0.000000
# 10010    BBRC02_E07859   normRange     Right-WM-hypointensities       0.000000
# 10010    BBRC02_E07859   normRange      Left-WM-hypointensities       0.000000

# %% [markdown]
# ### Creating new DataFrame only with Volume (mm3) measurements

# %% [markdown]
# #### ALFA_PLUS

# %%
#New dataframe with volume stats
stats_f6vol = stats_f6[stats_f6['measurement'] == 'Volume_mm3']

stats_f6vol.head()
# Out:
#                   ID measurement              region   value
# subject
# 10019    BBRC_E00046  Volume_mm3  WM-hypointensities  2255.2
# 10019    BBRC_E00046  Volume_mm3         CC_Anterior   644.2
# 10019    BBRC_E00046  Volume_mm3     CC_Mid_Anterior   263.1
# 10019    BBRC_E00046  Volume_mm3          CC_Central   297.6
# 10019    BBRC_E00046  Volume_mm3    CC_Mid_Posterior   279.5

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#New dataframe with volume stats
statsFreeS_AO = statsFreeS_AO[statsFreeS_AO['measurement'] == 'Volume_mm3']

statsFreeS_AO.head()
# Out:
#                     ID measurement           region          value
# subject
# 10010    BBRC02_E07859  Volume_mm3      lhCortexVol  223535.737235
# 10010    BBRC02_E07859  Volume_mm3      rhCortexVol  218948.843507
# 10010    BBRC02_E07859  Volume_mm3    5th-Ventricle       0.000000
# 10010    BBRC02_E07859  Volume_mm3  CC_Mid_Anterior     400.900000
# 10010    BBRC02_E07859  Volume_mm3       CC_Central     372.800000

# %% [markdown]
# ### List of regions that need to be fixed:

# %% [markdown]
# BrainSegVol, BrainSegVolNotVent, lhCerebralWhiteMatterVol, rhCerebralWhiteMatterVol, CerebralWhiteMatterVol, SubCortGrayVol, TotalGrayVol, SupraTentorialVol, SupraTentorialVolNotVent, MaskVol, BrainSegVol-to-eTIV, MaskVol-to-eTIV, lhCortexVol, rhCortexVol, CortexVol

# %%
reg_fix = ['BrainSegVol', 'BrainSegVolNotVent', 'lhCerebralWhiteMatterVol', 'rhCerebralWhiteMatterVol', 'CerebralWhiteMatterVol', 'SubCortGrayVol', 'TotalGrayVol', 'SupraTentorialVol', 'SupraTentorialVolNotVent', 'MaskVol', 'BrainSegVol-to-eTIV', 'MaskVol-to-eTIV', 'lhCortexVol', 'rhCortexVol', 'CortexVol']

# %% [markdown]
# #### ALFA_PLUS

# %%
regex_join = '^'+'$|^'.join(reg_fix)+'$'

VOLUME_CORRECTOR = 0.75**3
stats_f6vol.loc[stats_f6vol['region'].str.contains(regex_join), 'value'] = stats_f6vol.loc[stats_f6vol['region'].str.contains(regex_join), 'value'] * VOLUME_CORRECTOR
# Out:
# /home/jpozoc/miniconda3/envs/pyt3/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
regex_join = '^'+'$|^'.join(reg_fix)+'$'

VOLUME_CORRECTOR = 0.75**3
statsFreeS_AO.loc[statsFreeS_AO['region'].str.contains(regex_join), 'value'] = statsFreeS_AO.loc[statsFreeS_AO['region'].str.contains(regex_join), 'value'] * VOLUME_CORRECTOR

# %% [markdown]
# ### Reshaping the DataFrame to have the same format as the one with FastSurfer stats

# %% [markdown]
# #### ALFA_PLUS

# %%
#Reshaping the dataframe
statsFreeS = stats_f6vol.pivot_table(values='value', index=stats_f6vol.index, columns='region', aggfunc='first')

statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10019           2280.7         2919.5            0.0     22887.2
# 10026           1948.6         2111.0            0.0     18946.6
# 10032            901.5         1122.1            0.0     20236.2
# 10034            911.4         1793.3            0.0     18160.1
# 10036           2221.8         2651.8            0.0     18583.1
#
# region    BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10019    1.205194e+06        1.175871e+06            1.355871e+06
# 10026    1.095740e+06        1.045633e+06            1.145995e+06
# 10032    1.166636e+06        1.147179e+06            1.313665e+06
# 10034    1.069468e+06        1.048878e+06            1.208712e+06
# 10036    1.053200e+06        1.002218e+06            1.125398e+06
#
# region   CC_Anterior  CC_Central  CC_Mid_Anterior  ...  \
# subject                                            ...
# ...

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 66)
# (369, 61)

# %%
statsFastS.head()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10013           1961.1         1873.5              0     21146.6      1076960
# 10013           1939.1         1849.9              0     21262.4      1084001
# 10019           2335.3         3003.2              0     22947.8      1206855
# 10026           2017.8         2357.3              0     20385.5      1110897
# 10032           1020.2         1350.3              0     21828.4      1204293
#
#          BrainSegVol-to-eTIV  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10013               0.708702             1040879            1.041253e+06
# 10013               0.715196             1048161            1.048799e+06
# 10019               0.716136             1175093            1.175647e+06
# 10026               0.697698             1059210            1.059082e+06
# 10032               0.735471             1183601            1.184661e+06
#
# ...

# %%
statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10019           2280.7         2919.5            0.0     22887.2
# 10026           1948.6         2111.0            0.0     18946.6
# 10032            901.5         1122.1            0.0     20236.2
# 10034            911.4         1793.3            0.0     18160.1
# 10036           2221.8         2651.8            0.0     18583.1
#
# region    BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10019    1.205194e+06        1.175871e+06            1.355871e+06
# 10026    1.095740e+06        1.045633e+06            1.145995e+06
# 10032    1.166636e+06        1.147179e+06            1.313665e+06
# 10034    1.069468e+06        1.048878e+06            1.208712e+06
# 10036    1.053200e+06        1.002218e+06            1.125398e+06
#
# region   CC_Anterior  CC_Central  CC_Mid_Anterior  ...  \
# subject                                            ...
# ...

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#Reshaping the dataframe
statsFreeS_AO = statsFreeS_AO.pivot_table(values='value', index=statsFreeS_AO.index, columns='region', aggfunc='first')

statsFreeS_AO.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10010           1159.4         1573.8            0.0     23742.3
# 10011           1275.4         1295.1            0.0     19752.6
# 10012           1380.4         1170.0            0.0     20233.4
# 10014           1094.4         1844.8            0.0     18933.6
# 10016            687.6         1233.8            0.0     24217.7
#
# region    BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10010    1.120108e+06        1.094086e+06            1.279596e+06
# 10011    9.905536e+05        9.711305e+05            1.121663e+06
# 10012    1.060461e+06        1.030194e+06            1.161398e+06
# 10014    9.999252e+05        9.761669e+05            1.146797e+06
# 10016    1.138987e+06        1.125878e+06            1.324557e+06
#
# region   CC_Anterior  CC_Central  CC_Mid_Anterior  ...  \
# subject                                            ...
# ...

# %%
statsFreeS_AO.shape
# Out:
# (1070, 61)

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1184, 66)
# (1070, 61)

# %% [markdown]
# ### Checking common columns in both dataframes (if they are not common, they will be removed)

# %% [markdown]
# #### ALFA_PLUS

# %%
#if a column is not in the other dataframe, it is removed

column_notFastS = []
for column in statsFastS.columns:
    if column == 'Scan':
        continue
    elif column not in statsFreeS.columns:
        print(column)
        column_notFastS.append(column)
    else:
        continue
statsFastS.drop(column_notFastS,axis=1, inplace=True)

column_notFreeS = []
for column in statsFreeS.columns:
    if column not in statsFastS.columns:
        print(column)
        column_notFreeS.append(column)
    else:
        continue
statsFreeS.drop(column_notFreeS,axis=1, inplace=True)
# Out:
# BrainSegVol-to-eTIV
# CortexVol
# EstimatedTotalIntraCranialVol
# MaskVol-to-eTIV
# SurfaceHoles
# lhSurfaceHoles
# rhSurfaceHoles
# VentricleChoroidVol
# eTIV

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#if a column is not in the other dataframe, it is removed

column_notFastS = []
for column in statsFastS_AO.columns:
    if column == 'Scan':
        continue
    elif column not in statsFreeS_AO.columns:
        print(column)
        column_notFastS.append(column)
    else:
        continue
statsFastS_AO.drop(column_notFastS,axis=1, inplace=True)

column_notFreeS = []
for column in statsFreeS_AO.columns:
    if column not in statsFastS_AO.columns:
        print(column)
        column_notFreeS.append(column)
    else:
        continue
statsFreeS_AO.drop(column_notFreeS,axis=1, inplace=True)
# Out:
# BrainSegVol-to-eTIV
# CortexVol
# EstimatedTotalIntraCranialVol
# MaskVol-to-eTIV
# SurfaceHoles
# lhSurfaceHoles
# rhSurfaceHoles
# VentricleChoroidVol
# eTIV

# %% [markdown]
# ### We now see we have the same number of columns in both dataframes:

# %% [markdown]
# #### ALFA_PLUS

# %%
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 59)
# (369, 59)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1184, 59)
# (1070, 59)

# %% [markdown]
# ### Checking common rows in both dataframes (if they are not common, they will be removed)

# %% [markdown]
# #### ALFA_PLUS

# %%
#if a subject is not in the other dataframe, it is removed
indexFreeS = []
for index, row in statsFreeS.iterrows():
    indexFreeS.append(index)
#print(indexFreeS)
indexFastS = []
for index, row in statsFastS.iterrows():
    indexFastS.append(index)
    
print(len(indexFastS))
print(len(indexFreeS))

index_not = []
for i in range(len(indexFastS)):
    if indexFastS[i] not in indexFreeS:
        print(indexFastS[i])
        index_not.append(indexFastS[i])
        #statsFastS.drop(indexFastS[i], inplace=True)

    else:
        continue
statsFastS.drop(index_not, inplace=True)
# Out:
# 391
# 369
# 10013
# 10013
# 10651
# 10651
# 11309
# 11309
# 11491
# 11491
# 11872
# 11872
# 13135
# 13135
# 55395
# 55395
# 66020
# 66020
# 77072
# 77072

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#removing subjects with errors detected out of this notebook
statsFastS_AO.drop([11481,11803,13306], inplace=True)
statsFreeS_AO.drop([11481,11803,13306], inplace=True)

# %%
#if a subject is not in the other dataframe, it is removed
indexFreeS = []
for index, row in statsFreeS_AO.iterrows():
    indexFreeS.append(index)
#print(indexFreeS)
indexFastS = []
for index, row in statsFastS_AO.iterrows():
    indexFastS.append(index)
    
print(len(indexFastS))
print(len(indexFreeS))

index_not = []
for i in range(len(indexFastS)):
    if indexFastS[i] not in indexFreeS:
        print(indexFastS[i])
        index_not.append(indexFastS[i])
        #statsFastS.drop(indexFastS[i], inplace=True)

    else:
        continue
statsFastS_AO.drop(index_not, inplace=True)
# Out:
# 1181
# 1067
# 10310
# 10310
# 10317
# 10317
# 10362
# 10362
# 10393
# 10393
# 10419
# 10419
# 10419
# 10521
# 10521
# 10556
# 10811
# 10811
# 10942
# 10942
# 10971
# 10971
# 11144
# 11325
# 11325
# 11325
# 11332
# 11332
# 11614
# 11657
# 11657
# 11686
# 11686
# 11686
# 11807
# 12056
# 12056
# 12278
# 12278
# 12332
# 12521
# 12787
# 12787
# 12801
# 12801
# 13096
# 13096
# 13127
# 13320
# 13345
# 21026
# 21026
# 21085
# 21085
# 44006
# 44058
# 44092
# 44159
# 44159
# 44277
# 44289
# 44289
# 44331
# 44331
# 44343
# 44343
# 44393
# 44393
# 44494
# 44494
# 44632
# 44632
# 44632
# 44846
# 55062
# 55114
# 55202
# 55202
# 55289
# 55289
# 55687
# 55687
# 55687
# 55809
# 55874
# 55874
# 66015
# 66015
# 66015
# 66095
# 66095
# 66104
# 66104
# 66137
# 66137
# 66145
# 66145
# 66159
# 66159
# 66274
# 66274
# 66286
# 66286
# 77040
# 77040
# 77131
# 77131
# 77179
# 77209
# 77209

# %% [markdown]
# ### The number of rows have decreased in FastSurfer stats' dataframe. We will need to check later if there are any duplicated subjects

# %% [markdown]
# #### ALFA_PLUS

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (373, 59)
# (369, 59)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1073, 59)
# (1067, 59)

# %% [markdown]
# ### Removing those rows that are duplicated. We print the index location and then we remove them

# %% [markdown]
# #### ALFA_PLUS

# %%
lista = statsFastS.index.duplicated().tolist()
for i in [i for i,x in enumerate(lista) if x == 1]:
    print(i)
    
statsFastS = statsFastS[~statsFastS.index.duplicated(keep='first')] #removing duplicated subjects
# Out:
# 83
# 161
# 206
# 285

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
lista = statsFastS_AO.index.duplicated().tolist()
for i in [i for i,x in enumerate(lista) if x == 1]:
    print(i)
    
statsFastS_AO = statsFastS_AO[~statsFastS_AO.index.duplicated(keep='first')] #removing duplicated subjects
# Out:
# 160
# 195
# 253
# 858
# 914
# 1017

# %% [markdown]
# ### Now, we can see we have the same shape in both DataFrames

# %% [markdown]
# #### ALFA_PLUS

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (369, 59)
# (369, 59)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1067, 59)
# (1067, 59)

# %% [markdown]
# ## Concatenation of subjects from both datasets

# %%
statsFastSurfer = pd.concat([statsFastS,statsFastS_AO]).sort_index()

# %%
statsFastSurfer.head()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10010           1252.3         1545.0              0     23478.7      1130872
# 10011           1395.7         1464.9              0     20967.4      1013429
# 10012           1373.6         1385.9              0     21221.4      1074364
# 10014           1262.1         2172.9              0     19249.0      1004189
# 10016            869.7         1429.4              0     23659.8      1141082
#
#          BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  CC_Central  \
# subject
# 10010               1103652            1.103846e+06       1159.2       914.5
# 10011                993032            9.933133e+05        703.7       339.2
# 10012               1042517            1.042115e+06        981.2       712.4
# 10014                976928            9.771503e+05        870.0       467.3
# 10016               1125395            1.125598e+06        932.0       754.3
#
# ...

# %%
statsFastSurfer.shape
# Out:
# (1436, 59)

# %% [markdown]
# ### Adding a new column ('Software') in FreeSurfer stats' DataFrame and setting it as index, along with 'subject'

# %% [markdown]
# #### ALFA_PLUS

# %%
#we set both subject and Software as index in statsFreeS

statsFreeS['Software'] = 'FreeSurfer'
statsFreeS.reset_index(inplace=True)
statsFreeS.set_index(['subject','Software'], inplace= True)

# %%
statsFreeS.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10019   FreeSurfer         2280.7         2919.5            0.0     22887.2
# 10026   FreeSurfer         1948.6         2111.0            0.0     18946.6
# 10032   FreeSurfer          901.5         1122.1            0.0     20236.2
# 10034   FreeSurfer          911.4         1793.3            0.0     18160.1
# 10036   FreeSurfer         2221.8         2651.8            0.0     18583.1
#
# region               BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject Software
# 10019   FreeSurfer  1.205194e+06        1.175871e+06            1.355871e+06
# 10026   FreeSurfer  1.095740e+06        1.045633e+06            1.145995e+06
# 10032   FreeSurfer  1.166636e+06        1.147179e+06            1.313665e+06
# 10034   FreeSurfer  1.069468e+06        1.048878e+06            1.208712e+06
# 10036   FreeSurfer  1.053200e+06        1.002218e+06            1.125398e+06
#
# ...

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#we set both subject and Software as index in statsFreeS

statsFreeS_AO['Software'] = 'FreeSurfer'
statsFreeS_AO.reset_index(inplace=True)
statsFreeS_AO.set_index(['subject','Software'], inplace= True)

# %%
statsFreeS_AO.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FreeSurfer         1159.4         1573.8            0.0     23742.3
# 10011   FreeSurfer         1275.4         1295.1            0.0     19752.6
# 10012   FreeSurfer         1380.4         1170.0            0.0     20233.4
# 10014   FreeSurfer         1094.4         1844.8            0.0     18933.6
# 10016   FreeSurfer          687.6         1233.8            0.0     24217.7
#
# region               BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject Software
# 10010   FreeSurfer  1.120108e+06        1.094086e+06            1.279596e+06
# 10011   FreeSurfer  9.905536e+05        9.711305e+05            1.121663e+06
# 10012   FreeSurfer  1.060461e+06        1.030194e+06            1.161398e+06
# 10014   FreeSurfer  9.999252e+05        9.761669e+05            1.146797e+06
# 10016   FreeSurfer  1.138987e+06        1.125878e+06            1.324557e+06
#
# ...

# %% [markdown]
# ### Adding the column 'Software' in FastSurfer stats' DataFrame and setting it as index, along with 'subject'

# %%
#we set both subject and Software as index in statsFastS

statsFastSurfer['Software'] ='FastSurfer'
statsFastSurfer.reset_index(inplace=True)
statsFastSurfer.set_index(['subject','Software'], inplace= True)

# %%
statsFastSurfer.head()
# Out:
#                     3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FastSurfer         1252.3         1545.0              0     23478.7
# 10011   FastSurfer         1395.7         1464.9              0     20967.4
# 10012   FastSurfer         1373.6         1385.9              0     21221.4
# 10014   FastSurfer         1262.1         2172.9              0     19249.0
# 10016   FastSurfer          869.7         1429.4              0     23659.8
#
#                     BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject Software
# 10010   FastSurfer      1130872             1103652            1.103846e+06
# 10011   FastSurfer      1013429              993032            9.933133e+05
# 10012   FastSurfer      1074364             1042517            1.042115e+06
# 10014   FastSurfer      1004189              976928            9.771503e+05
# 10016   FastSurfer      1141082             1125395            1.125598e+06
#
# ...

# %% [markdown]
# # 3. Describing FreeSurfer subjects stats

# %% [markdown]
# ## Concatenation of subjects from both datasets

# %%
statsFreeSurfer = pd.concat([statsFreeS,statsFreeS_AO]).sort_index()

# %%
statsFreeSurfer.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FreeSurfer         1159.4         1573.8            0.0     23742.3
# 10011   FreeSurfer         1275.4         1295.1            0.0     19752.6
# 10012   FreeSurfer         1380.4         1170.0            0.0     20233.4
# 10014   FreeSurfer         1094.4         1844.8            0.0     18933.6
# 10016   FreeSurfer          687.6         1233.8            0.0     24217.7
#
# region               BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject Software
# 10010   FreeSurfer  1.120108e+06        1.094086e+06            1.279596e+06
# 10011   FreeSurfer  9.905536e+05        9.711305e+05            1.121663e+06
# 10012   FreeSurfer  1.060461e+06        1.030194e+06            1.161398e+06
# 10014   FreeSurfer  9.999252e+05        9.761669e+05            1.146797e+06
# 10016   FreeSurfer  1.138987e+06        1.125878e+06            1.324557e+06
#
# ...

# %%
#shape
statsFreeSurfer.shape
# Out:
# (1436, 59)

# %%
statsFastSurfer.shape
# Out:
# (1436, 59)

# %% [markdown]
# ### Describing FreeSurfer stats' DataFrame

# %%
statsFreeSurfer.describe()
# Out:
# region  3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count     1436.000000    1436.000000    1436.000000   1436.000000
# mean      1269.649721    1756.532521       0.071100  20348.103134
# std        491.065262     485.621896       0.746369   2245.725544
# min        453.600000     729.100000       0.000000  15010.000000
# 25%        915.450000    1418.850000       0.000000  18763.875000
# 50%       1163.950000    1669.300000       0.000000  20203.650000
# 75%       1512.350000    2022.000000       0.000000  21817.225000
# max       4393.400000    6206.600000      19.000000  27882.700000
#
# region   BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  CC_Anterior  \
# count   1.436000e+03        1.436000e+03            1.436000e+03  1436.000000
# mean    1.058744e+06        1.032084e+06            1.188980e+06   658.227228
# std     1.017923e+05        9.844307e+04            1.100488e+05   110.872662
# ...

# %% [markdown]
# ### Correlation map to check if variables are correlated

# %%
#Correlation Map

f, ax = plt.subplots(figsize=(50, 50))
corr = statsFreeSurfer.corr()
sns.heatmap(corr,annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# # 4. Creating a common DataFrame with FreeSurfer and FastSurfer stats

# %% [markdown]
# ### Concatenating both DataFrames to put them together

# %%
concat_df = pd.concat([statsFastSurfer,statsFreeSurfer]).sort_index()

concat_df.head(10)
# Out:
#                     3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FastSurfer         1252.3         1545.0            0.0     23478.7
#         FreeSurfer         1159.4         1573.8            0.0     23742.3
# 10011   FastSurfer         1395.7         1464.9            0.0     20967.4
#         FreeSurfer         1275.4         1295.1            0.0     19752.6
# 10012   FastSurfer         1373.6         1385.9            0.0     21221.4
#         FreeSurfer         1380.4         1170.0            0.0     20233.4
# 10014   FastSurfer         1262.1         2172.9            0.0     19249.0
#         FreeSurfer         1094.4         1844.8            0.0     18933.6
# 10016   FastSurfer          869.7         1429.4            0.0     23659.8
#         FreeSurfer          687.6         1233.8            0.0     24217.7
#
#                      BrainSegVol  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject Software
# ...

# %%
concat_df.shape
# Out:
# (2872, 59)

# %% [markdown]
# ### Saving the DataFrame to analyse it in other notebook

# %%
concat_df.to_pickle('all_stats.pkl')

# %%
statsFastSurfer.to_pickle('statsFastSurfer.pkl')
statsFreeSurfer.to_pickle('statsFreeSurfer.pkl')
