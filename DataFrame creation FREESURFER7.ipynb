# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import os

# %% [markdown]
# # 1. Describing FastSurfer subjects stats

# %% [markdown]
# ### Creation of DataFrame with FastSurfer stats (ALFA_PLUS subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_PLUS subjects

statsFastS = pd.read_csv('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/aseg_stats.csv')

# %%
#first 5 rows of DataFrame

statsFastS.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0               0                 15027.1              641.9
# 1               1                 15028.7              809.5
# 2               2                 10931.6              760.5
# 3               3                 21022.3              886.6
# 4               4                  7773.4              533.2
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       14518.4                 49024.5                5880.1
# 1                       14101.8                 49310.6                6153.4
# 2                       13588.4                 56167.5                7061.4
# 3                       11670.9                 40964.6                6156.1
# 4                       14658.8                 49447.8                7429.0
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        3105.0        5069.1         1769.0         1961.1  ...
# 1        3034.4        4836.5         1647.6         1939.1  ...
# 2        3354.8        5029.7         2194.0         2335.3  ...
# 3        2948.7        4228.8         1666.8         2017.8  ...
# 4        2861.1        4758.4         1898.1         1020.2  ...
#
#    SupraTentorialVol  SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  \
# 0       9.508758e+05              9.194948e+05                       918107
# 1       9.577320e+05              9.265220e+05                       924839
# 2       1.066739e+06              1.041607e+06                      1039981
# 3       1.002746e+06              9.567843e+05                       956002
# 4       1.077000e+06              1.059472e+06                      1057021
#
#    MaskVol  BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  \
# 0  1372434             0.708702         0.903141              21
# 1  1375126             0.715196         0.907273              46
# 2  1478575             0.716136         0.877372              28
# 3  1442353             0.697698         0.905868              23
# 4  1474878             0.735471         0.900720              11
#
#    rhSurfaceHoles  SurfaceHoles  EstimatedTotalIntraCranialVol
# 0              23            44                   1.519623e+06
# 1              24            70                   1.515670e+06
# 2              17            45                   1.685232e+06
# 3              29            52                   1.592233e+06
# 4              12            23                   1.637444e+06
#
# [5 rows x 67 columns]

# %%
scans = []

for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/Archivos_ALFAPLUS_security_copy'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        scans.append(int(filename.split("_")[2]))
print(scans)
# Out:
# [1401, 301, 301, 201, 1201, 401, 401, 401, 401, 401, 401, 301, 301, 301, 301, 401, 401, 401, 301, 301, 1401, 301, 401, 301, 401, 401, 1401, 401, 301, 301, 301, 201, 201, 301, 401, 201, 301, 1401, 401, 201, 201, 201, 401, 401, 401, 401, 1401, 201, 201, 301, 401, 301, 201, 401, 401, 301, 301, 401, 401, 1401, 401, 301, 401, 301, 301, 201, 301, 901, 201, 301, 901, 401, 201, 301, 1401, 201, 401, 1401, 201, 301, 401, 301, 401, 301, 201, 1101, 301, 401, 201, 401, 301, 401, 1901, 301, 401, 401, 301, 401, 301, 401, 501, 301, 501, 301, 201, 401, 201, 301, 301, 301, 201, 201, 201, 201, 401, 401, 901, 301, 301, 401, 201, 1401, 401, 401, 501, 401, 401, 201, 401, 301, 401, 301, 301, 401, 401, 1501, 401, 201, 1601, 301, 301, 901, 201, 301, 201, 401, 401, 901, 1401, 301, 301, 201, 401, 201, 301, 401, 401, 301, 401, 301, 401, 301, 301, 301, 301, 301, 301, 401, 201, 301, 1501, 401, 1401, 401, 401, 401, 401, 201, 301, 401, 501, 301, 301, 301, 401, 401, 401, 401, 1601, 301, 201, 401, 301, 401, 301, 401, 301, 301, 401, 301, 401, 201, 1401, 401, 1401, 201, 301, 201, 301, 301, 301, 301, 701, 201, 201, 401, 401, 701, 401, 301, 301, 1401, 401, 301, 401, 401, 201, 401, 201, 401, 401, 301, 301, 201, 401, 301, 1401, 1501, 301, 401, 401, 401, 401, 201, 501, 301, 401, 401, 401, 401, 201, 301, 301, 401, 401, 501, 301, 1401, 401, 301, 1401, 401, 301, 201, 401, 401, 301, 401, 301, 201, 301, 201, 401, 401, 1401, 401, 201, 401, 401, 401, 301, 401, 401, 401, 301, 201, 301, 401, 301, 301, 201, 201, 301, 1501, 301, 401, 301, 301, 401, 401, 1401, 401, 201, 1401, 301, 301, 301, 401, 501, 401, 1401, 401, 301, 401, 301, 301, 201, 401, 401, 301, 401, 1001, 401, 1401, 301, 301, 301, 201, 301, 301, 401, 901, 301, 201, 401, 301, 401, 401, 301, 401, 401, 301, 201, 401, 201, 301, 1401, 401, 301, 401, 301, 301, 301, 201, 501, 201, 301, 301, 301, 1501, 201, 501, 401, 401, 501, 301, 401, 1501, 301, 301, 401, 501, 401, 301, 301, 301, 401, 401, 401, 901, 401, 401, 301, 901, 201, 301, 201, 401, 401, 1601, 401]

# %% [markdown]
# ### Creation of DataFrame with FastSurfer stats (ALFA_OPCIONAL subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_OPCIONAL subjects

statsFastS_AO = pd.read_csv('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/stats_ALFA_OPCIONAL.csv')

# %%
#first 5 rows of DataFrame

statsFastS_AO.head()
# Out:
#    Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0               0                 10682.6              502.0
# 1               1                  8106.8              456.0
# 2               2                 12982.6              704.8
# 3               3                 11437.9              841.0
# 4               4                  5106.4              768.9
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       16251.3                 55801.7                7752.9
# 1                       11804.6                 47019.3                6500.4
# 2                       12580.7                 45940.6                6759.9
# 3                       11674.1                 53769.6                5649.2
# 4                       14600.3                 54463.1                6753.7
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        3020.4        5141.0         2082.6         1252.3  ...
# 1        2819.2        4847.4         1631.5         1395.7  ...
# 2        2971.5        4167.3         1589.1         1373.6  ...
# 3        2814.0        3898.0         1599.0         1262.1  ...
# 4        3008.0        4912.5         2428.2          869.7  ...
#
#    SupraTentorialVol  SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  \
# 0       9.853291e+05             962081.127032                       960743
# 1       8.956513e+05             879223.319629                       877813
# 2       9.587228e+05             930585.844341                       930082
# 3       8.753833e+05             852697.330292                       851666
# 4       1.006365e+06             994089.588492                       992765
#
#    MaskVol  BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  \
# 0  1428881             0.711406         0.898876              27
# 1  1306254             0.701999         0.904838              20
# 2  1355288             0.726819         0.916867              20
# 3  1259239             0.706125         0.885471              21
# 4  1397688             0.736068         0.901594              36
#
#    rhSurfaceHoles  SurfaceHoles  EstimatedTotalIntraCranialVol
# 0              31            58                   1.589631e+06
# 1              27            47                   1.443633e+06
# 2              39            59                   1.478173e+06
# 3              20            41                   1.422111e+06
# 4              18            54                   1.550241e+06
#
# [5 rows x 67 columns]

# %% [markdown]
# ### Replacing column name (Measure:volume >> subject), modifying his values and setting 'subject' as index

# %% [markdown]
# #### ALFA_PLUS

# %%
#renaming values of Measure:volume column

names = []
scans = []
for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/Archivos_ALFAPLUS_security_copy'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        names.append(int(filename[0:5]))
        scans.append(int(filename.split("_")[2]))
for i in range(0,statsFastS.shape[0]):
    statsFastS["Measure:volume"].replace({i: names[i]}, inplace=True)

#statsFastS['Scan'] = scans    
#rename column    
statsFastS.rename(columns={'Measure:volume': 'subject'}, inplace=True)

#set subject as index
statsFastS.set_index('subject', inplace= True)

statsFastS.head()
# Out:
#          Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# subject
# 10013                   15027.1              641.9
# 10013                   15028.7              809.5
# 10019                   10931.6              760.5
# 10026                   21022.3              886.6
# 10032                    7773.4              533.2
#
#          Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# subject
# 10013                         14518.4                 49024.5
# 10013                         14101.8                 49310.6
# 10019                         13588.4                 56167.5
# 10026                         11670.9                 40964.6
# 10032                         14658.8                 49447.8
#
#          Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# subject
# 10013                  5880.1        3105.0        5069.1         1769.0
# 10013                  6153.4        3034.4        4836.5         1647.6
# 10019                  7061.4        3354.8        5029.7         2194.0
# 10026                  6156.1        2948.7        4228.8         1666.8
# 10032                  7429.0        2861.1        4758.4         1898.1
#
#          3rd-Ventricle  4th-Ventricle  ...  SupraTentorialVol  \
# subject                                ...
# 10013           1961.1         1873.5  ...       9.508758e+05
# 10013           1939.1         1849.9  ...       9.577320e+05
# 10019           2335.3         3003.2  ...       1.066739e+06
# 10026           2017.8         2357.3  ...       1.002746e+06
# 10032           1020.2         1350.3  ...       1.077000e+06
#
#          SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  MaskVol  \
# subject
# 10013                9.194948e+05                       918107  1372434
# 10013                9.265220e+05                       924839  1375126
# 10019                1.041607e+06                      1039981  1478575
# 10026                9.567843e+05                       956002  1442353
# 10032                1.059472e+06                      1057021  1474878
#
#          BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles  \
# subject
# 10013               0.708702         0.903141              21              23
# 10013               0.715196         0.907273              46              24
# 10019               0.716136         0.877372              28              17
# 10026               0.697698         0.905868              23              29
# 10032               0.735471         0.900720              11              12
#
#          SurfaceHoles  EstimatedTotalIntraCranialVol
# subject
# 10013              44                   1.519623e+06
# 10013              70                   1.515670e+06
# 10019              45                   1.685232e+06
# 10026              52                   1.592233e+06
# 10032              23                   1.637444e+06
#
# [5 rows x 66 columns]

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#renaming values of Measure:volume column

names = []
#scans = []
for path, subdirs, files in os.walk(r'/home/jpozoc/barracuda/jpozoc/ALFA_OPCIONAL_security'):
    sorted_files = sorted(files)
    for filename in sorted_files:
        names.append(int(filename[0:5]))
        #scans.append(int(filename.split("_")[2]))
for i in range(0,statsFastS_AO.shape[0]):
    statsFastS_AO["Measure:volume"].replace({i: names[i]}, inplace=True)

#statsFastS['Scan'] = scans    
#rename column    
statsFastS_AO.rename(columns={'Measure:volume': 'subject'}, inplace=True)

#set subject as index
statsFastS_AO.set_index('subject', inplace= True)

statsFastS_AO.head()
# Out:
#          Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# subject
# 10010                   10682.6              502.0
# 10011                    8106.8              456.0
# 10012                   12982.6              704.8
# 10014                   11437.9              841.0
# 10016                    5106.4              768.9
#
#          Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# subject
# 10010                         16251.3                 55801.7
# 10011                         11804.6                 47019.3
# 10012                         12580.7                 45940.6
# 10014                         11674.1                 53769.6
# 10016                         14600.3                 54463.1
#
#          Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# subject
# 10010                  7752.9        3020.4        5141.0         2082.6
# 10011                  6500.4        2819.2        4847.4         1631.5
# 10012                  6759.9        2971.5        4167.3         1589.1
# 10014                  5649.2        2814.0        3898.0         1599.0
# 10016                  6753.7        3008.0        4912.5         2428.2
#
#          3rd-Ventricle  4th-Ventricle  ...  SupraTentorialVol  \
# subject                                ...
# 10010           1252.3         1545.0  ...       9.853291e+05
# 10011           1395.7         1464.9  ...       8.956513e+05
# 10012           1373.6         1385.9  ...       9.587228e+05
# 10014           1262.1         2172.9  ...       8.753833e+05
# 10016            869.7         1429.4  ...       1.006365e+06
#
#          SupraTentorialVolNotVent  SupraTentorialVolNotVentVox  MaskVol  \
# subject
# 10010               962081.127032                       960743  1428881
# 10011               879223.319629                       877813  1306254
# 10012               930585.844341                       930082  1355288
# 10014               852697.330292                       851666  1259239
# 10016               994089.588492                       992765  1397688
#
#          BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles  \
# subject
# 10010               0.711406         0.898876              27              31
# 10011               0.701999         0.904838              20              27
# 10012               0.726819         0.916867              20              39
# 10014               0.706125         0.885471              21              20
# 10016               0.736068         0.901594              36              18
#
#          SurfaceHoles  EstimatedTotalIntraCranialVol
# subject
# 10010              58                   1.589631e+06
# 10011              47                   1.443633e+06
# 10012              59                   1.478173e+06
# 10014              41                   1.422111e+06
# 10016              54                   1.550241e+06
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Sorting column names alphabetically

# %% [markdown]
# #### ALFA_PLUS

# %%
#sort column names
statsFastS = statsFastS.reindex(sorted(statsFastS.columns), axis=1)

statsFastS.describe()
# Out:
#        3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count     391.000000     391.000000          391.0    391.000000
# mean     1369.234783    1895.917647            0.0  20949.216880
# std       478.733565     473.634846            0.0   2203.918287
# min       542.200000     731.600000            0.0  15581.500000
# 25%      1019.400000    1553.250000            0.0  19507.550000
# 50%      1271.400000    1810.100000            0.0  20820.100000
# 75%      1649.450000    2136.000000            0.0  22493.350000
# max      3544.300000    3768.100000            0.0  27782.100000
#
#         BrainSegVol  BrainSegVol-to-eTIV  BrainSegVolNotVent  \
# count  3.910000e+02           391.000000        3.910000e+02
# mean   1.072269e+06             0.726004        1.043221e+06
# std    1.037948e+05             0.026561        9.904662e+04
# min    8.400910e+05             0.661940        8.173580e+05
# 25%    9.992830e+05             0.710196        9.715210e+05
# 50%    1.069028e+06             0.723749        1.041135e+06
# 75%    1.141720e+06             0.740565        1.111820e+06
# max    1.387998e+06             0.911184        1.307269e+06
#
#        BrainSegVolNotVentSurf  CC_Anterior   CC_Central  ...  SurfaceHoles  \
# count            3.910000e+02   391.000000   391.000000  ...    391.000000
# mean             1.043585e+06   918.318926   626.058568  ...     49.521739
# std              9.909316e+04   167.297810   158.863589  ...     35.230798
# min              8.173956e+05   454.100000   269.500000  ...     12.000000
# 25%              9.720620e+05   805.800000   498.150000  ...     30.000000
# 50%              1.041253e+06   911.800000   628.500000  ...     42.000000
# 75%              1.112186e+06  1016.400000   745.350000  ...     57.500000
# max              1.308019e+06  1385.600000  1149.200000  ...    356.000000
#
#         TotalGrayVol  WM-hypointensities  lhCerebralWhiteMatterVol  \
# count     391.000000          391.000000                391.000000
# mean   587636.226003         2482.513555             216035.931653
# std     49637.388634         2693.581906              25755.318579
# min    470458.847313          685.200000             153163.715313
# 25%    552814.760273         1340.900000             196360.423314
# 50%    587564.484320         1699.200000             214391.321402
# 75%    619854.672622         2630.150000             233953.781299
# max    733674.426033        26763.000000             282353.513531
#
#          lhCortexVol  lhSurfaceHoles  non-WM-hypointensities  \
# count     391.000000      391.000000                   391.0
# mean   218996.653107       24.421995                     0.0
# std     19771.941679       17.760181                     0.0
# min    173294.575857        3.000000                     0.0
# 25%    204962.156559       14.000000                     0.0
# 50%    217469.514099       20.000000                     0.0
# 75%    231954.474538       28.500000                     0.0
# max    282725.569089      179.000000                     0.0
#
#        rhCerebralWhiteMatterVol    rhCortexVol  rhSurfaceHoles
# count                391.000000     391.000000      391.000000
# mean              215954.530729  219296.002564       25.099744
# std                25598.015080   19671.707826       19.189548
# min               153744.072130  165726.271456        3.000000
# 25%               197932.076791  205164.027353       15.000000
# 50%               215416.673620  218711.163010       21.000000
# 75%               234150.805652  231628.215223       29.000000
# max               276971.491337  282556.856944      177.000000
#
# [8 rows x 66 columns]

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#sort column names
statsFastS_AO = statsFastS_AO.reindex(sorted(statsFastS_AO.columns), axis=1)

statsFastS_AO.describe()
# Out:
#        3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count    1184.000000    1184.000000         1184.0   1184.000000
# mean     1329.743919    1904.898818            0.0  20950.567230
# std       477.803566     450.570807            0.0   2197.811505
# min       572.100000     819.700000            0.0  15354.600000
# 25%       981.975000    1585.950000            0.0  19452.400000
# 50%      1230.850000    1833.850000            0.0  20742.300000
# 75%      1560.250000    2160.850000            0.0  22430.775000
# max      4341.000000    5157.900000            0.0  28227.300000
#
#         BrainSegVol  BrainSegVol-to-eTIV  BrainSegVolNotVent  \
# count  1.184000e+03          1184.000000        1.184000e+03
# mean   1.070169e+06             0.724459        1.041260e+06
# std    1.017102e+05             0.030930        9.843763e+04
# min    7.908040e+05             0.605515        7.660560e+05
# 25%    9.954105e+05             0.706312        9.713968e+05
# 50%    1.065956e+06             0.722885        1.036412e+06
# 75%    1.138334e+06             0.739949        1.108332e+06
# max    1.386480e+06             1.010167        1.332914e+06
#
#        BrainSegVolNotVentSurf  CC_Anterior   CC_Central  ...  SurfaceHoles  \
# count            1.184000e+03  1184.000000  1184.000000  ...   1184.000000
# mean             1.041628e+06   910.766639   611.014189  ...     54.100507
# std              9.849642e+04   178.098111   164.877980  ...     44.060869
# min              7.666097e+05   476.300000   249.700000  ...      9.000000
# 25%              9.716698e+05   786.675000   478.525000  ...     29.000000
# 50%              1.036709e+06   893.000000   612.850000  ...     42.000000
# 75%              1.108817e+06  1021.800000   731.700000  ...     64.000000
# max              1.333821e+06  1524.800000  1146.200000  ...    503.000000
#
#         TotalGrayVol  WM-hypointensities  lhCerebralWhiteMatterVol  \
# count    1184.000000          1184.00000               1184.000000
# mean   588910.610676          2354.60625             214567.389156
# std     49752.913968          2100.55983              25588.109177
# min    447401.519428           632.30000             144593.147366
# 25%    553973.043422          1307.22500             195490.966958
# 50%    586813.044620          1722.60000             213262.021979
# 75%    619249.627736          2569.80000             232289.676900
# max    765834.203571         30672.10000             303838.387755
#
#          lhCortexVol  lhSurfaceHoles  non-WM-hypointensities  \
# count    1184.000000     1184.000000                  1184.0
# mean   219618.790976       26.747466                     0.0
# std     19890.618782       21.718274                     0.0
# min    163260.322720        2.000000                     0.0
# 25%    205204.109087       14.000000                     0.0
# 50%    218810.928275       21.000000                     0.0
# 75%    232156.217000       32.000000                     0.0
# max    297953.687467      224.000000                     0.0
#
#        rhCerebralWhiteMatterVol    rhCortexVol  rhSurfaceHoles
# count               1184.000000    1184.000000     1184.000000
# mean              214572.304576  220134.272403       27.353041
# std                25574.599029   20109.413370       23.955799
# min               146847.724657  164727.196708        2.000000
# 25%               195753.623441  206509.811804       14.000000
# 50%               213448.537308  219162.715700       21.000000
# 75%               231839.001653  232447.770454       32.000000
# max               304417.018195  294506.516104      279.000000
#
# [8 rows x 66 columns]

# %%
#statsFastS['Scan']

# %%
#DataFrame shape
print(statsFastS.shape)
print(statsFastS_AO.shape)
# Out:
# (391, 66)
# (1184, 66)

# %%
# Unique values per column
print(statsFastS.nunique())
# Out:
# 3rd-Ventricle               386
# 4th-Ventricle               388
# 5th-Ventricle                 1
# Brain-Stem                  389
# BrainSegVol                 391
#                            ...
# lhSurfaceHoles               66
# non-WM-hypointensities        1
# rhCerebralWhiteMatterVol    391
# rhCortexVol                 391
# rhSurfaceHoles               62
# Length: 66, dtype: int64

# %%
# Unique values per column
print(statsFastS_AO.nunique())
# Out:
# 3rd-Ventricle               1123
# 4th-Ventricle               1131
# 5th-Ventricle                  1
# Brain-Stem                  1171
# BrainSegVol                 1178
#                             ...
# lhSurfaceHoles               100
# non-WM-hypointensities         1
# rhCerebralWhiteMatterVol    1179
# rhCortexVol                 1179
# rhSurfaceHoles               106
# Length: 66, dtype: int64

# %%
# Missing values
statsFastS.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Correlation map to check if variables are correlated

# %%
#Correlation map
f, ax = plt.subplots(figsize=(50, 50))
corr = statsFastS.corr()
sns.heatmap(corr,annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# # 2. Adapting FastSurfer and FreeSurfer DataFrames

# %% [markdown]
# ### Creation of DataFrame with FreeSurfer stats (ALFA_PLUS subjects)

# %%
#reading csv file and creating DataFrame with FastSurfer stats containing ALFA_PLUS subjects

stats_f6 = pd.read_excel('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/ALFAPLUS_aseg_FREESURFER7/bx_freesurfer6_ALFA_PLUS_20210619_122954.xlsx')

# %%
#first 5 rows of DataFrame

stats_f6.head()
# Out:
#               ID measurement                region   value  subject
# 0  BBRC02_E00014   normRange           CC_Anterior    94.0    10994
# 1  BBRC02_E00014     NVoxels        Right-Pallidum  4088.0    10994
# 2  BBRC02_E00014     NVoxels     Right-Hippocampus  9658.0    10994
# 3  BBRC02_E00014     NVoxels        Right-Amygdala  3332.0    10994
# 4  BBRC02_E00014     NVoxels  Right-Accumbens-area  1202.0    10994

# %% [markdown]
# ### Creation of DataFrame with FreeSurfer stats (ALFA_OPCIONAL subjects)

# %%
statsFreeS_AO = pd.read_excel('/home/jpozoc/barracuda/jpozoc/Barcelonabeta-Project/ALFAPLUS_aseg_FREESURFER7/bx_freesurfer6_ALFA_OPCIONAL_20210619_151257.xlsx')

# %%
statsFreeS_AO.head()
# Out:
#               ID measurement                region      value  subject
# 0  BBRC02_E00002    normMean         Left-Amygdala    51.0774    13060
# 1  BBRC02_E00002     NVoxels     Right-Hippocampus  9603.0000    13060
# 2  BBRC02_E00002     NVoxels        Right-Amygdala  4035.0000    13060
# 3  BBRC02_E00002     NVoxels  Right-Accumbens-area  1225.0000    13060
# 4  BBRC02_E00002     NVoxels       Right-VentralDC  9627.0000    13060

# %% [markdown]
# ### Setting 'subject' as index and sorting columns alphabetically

# %% [markdown]
# #### ALFA_PLUS

# %%
stats_f6.set_index('subject', inplace= True)
stats_f6.sort_index(inplace=True)

stats_f6.head()
# Out:
#                   ID measurement                region   value
# subject
# 10019    BBRC_E00046     NVoxels  Right-choroid-plexus  1348.0
# 10019    BBRC_E00046   normRange       CC_Mid_Anterior    94.0
# 10019    BBRC_E00046   normRange            CC_Central    88.0
# 10019    BBRC_E00046   normRange      CC_Mid_Posterior   105.0
# 10019    BBRC_E00046   normRange          CC_Posterior    89.0

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
statsFreeS_AO.set_index('subject', inplace= True)
statsFreeS_AO.sort_index(inplace=True)

statsFreeS_AO.head()
# Out:
#                     ID measurement                    region          value
# subject
# 10010    BBRC02_E07859  Volume_mm3         Left-Inf-Lat-Vent     301.500000
# 10010    BBRC02_E07859  Volume_mm3               lhCortexVol  223312.769133
# 10010    BBRC02_E07859  Volume_mm3               rhCortexVol  220056.003802
# 10010    BBRC02_E07859  Volume_mm3  lhCerebralWhiteMatterVol  233609.484375
# 10010    BBRC02_E07859  Volume_mm3  rhCerebralWhiteMatterVol  228810.234375

# %% [markdown]
# ### Creating new DataFrame only with Volume (mm3) measurements

# %% [markdown]
# #### ALFA_PLUS

# %%
#New dataframe with volume stats
stats_f6vol = stats_f6[stats_f6['measurement'] == 'Volume_mm3']

stats_f6vol.head()
# Out:
#                   ID measurement            region  value
# subject
# 10019    BBRC_E00046  Volume_mm3       CC_Anterior  627.5
# 10019    BBRC_E00046  Volume_mm3   CC_Mid_Anterior  264.2
# 10019    BBRC_E00046  Volume_mm3        CC_Central  295.7
# 10019    BBRC_E00046  Volume_mm3  CC_Mid_Posterior  281.9
# 10019    BBRC_E00046  Volume_mm3      CC_Posterior  514.5

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#New dataframe with volume stats
statsFreeS_AO = statsFreeS_AO[statsFreeS_AO['measurement'] == 'Volume_mm3']

statsFreeS_AO.head()
# Out:
#                     ID measurement                    region          value
# subject
# 10010    BBRC02_E07859  Volume_mm3         Left-Inf-Lat-Vent     301.500000
# 10010    BBRC02_E07859  Volume_mm3               lhCortexVol  223312.769133
# 10010    BBRC02_E07859  Volume_mm3               rhCortexVol  220056.003802
# 10010    BBRC02_E07859  Volume_mm3  lhCerebralWhiteMatterVol  233609.484375
# 10010    BBRC02_E07859  Volume_mm3  rhCerebralWhiteMatterVol  228810.234375

# %% [markdown]
# ### Reshaping the DataFrame to have the same format as the one with FastSurfer stats

# %% [markdown]
# #### ALFA_PLUS

# %%
#Reshaping the dataframe
statsFreeS = stats_f6vol.pivot_table(values='value', index=stats_f6vol.index, columns='region', aggfunc='first')

statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10019           2132.3         2754.8            0.0     22960.8
# 10026           1957.3         2178.0            0.0     20069.7
# 10032            899.8         1068.0            0.0     21077.7
# 10034           1000.5         1658.9            0.0     18384.2
# 10036           2199.7         2524.1            0.0     18645.0
#
# region    BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject
# 10019    1.222108e+06        1.192832e+06        627.5       295.7
# 10026    1.105547e+06        1.054933e+06        671.0       304.7
# 10032    1.212473e+06        1.193060e+06        818.4       457.0
# 10034    1.094593e+06        1.073541e+06        701.7       318.1
# 10036    1.070421e+06        1.019344e+06        682.8       261.7
#
# region   CC_Mid_Anterior  CC_Mid_Posterior  ...  SupraTentorialVolNotVent  \
# subject                                     ...
# 10019              264.2             281.9  ...              1.046722e+06
# 10026              328.3             297.4  ...              9.472373e+05
# 10032              512.6             517.6  ...              1.061598e+06
# 10034              334.5             386.4  ...              9.467748e+05
# 10036              294.3             272.3  ...              8.914106e+05
#
# region    TotalGrayVol  VentricleChoroidVol  WM-hypointensities          eTIV  \
# subject
# 10019    683440.609488         23230.546875              1985.0  1.674232e+06
# 10026    612632.631417         45083.254663              2609.7  1.601848e+06
# 10032    634957.815632         16796.469001              1179.2  1.621333e+06
# 10034    596388.219371         17671.500000              1524.3  1.414327e+06
# 10036    595379.896448         45382.858763              2055.4  1.469776e+06
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10019               240172.382812  253798.614247                     0.0
# 10026               211435.254261  240081.877244                     0.0
# 10032               262423.154931  236897.055211                     0.0
# 10034               225925.031250  222024.116193                     0.0
# 10036               198479.133283  219840.289918                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10019               240514.523438  254927.104616
# 10026               209418.710423  235707.583055
# 10032               268261.736645  239485.893522
# 10034               226789.453125  220406.306303
# 10036               199891.546936  222720.077337
#
# [5 rows x 59 columns]

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 66)
# (369, 59)

# %%
statsFastS.head()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10013           1961.1         1873.5              0     21146.6      1076960
# 10013           1939.1         1849.9              0     21262.4      1084001
# 10019           2335.3         3003.2              0     22947.8      1206855
# 10026           2017.8         2357.3              0     20385.5      1110897
# 10032           1020.2         1350.3              0     21828.4      1204293
#
#          BrainSegVol-to-eTIV  BrainSegVolNotVent  BrainSegVolNotVentSurf  \
# subject
# 10013               0.708702             1040879            1.041253e+06
# 10013               0.715196             1048161            1.048799e+06
# 10019               0.716136             1175093            1.175647e+06
# 10026               0.697698             1059210            1.059082e+06
# 10032               0.735471             1183601            1.184661e+06
#
#          CC_Anterior  CC_Central  ...  SurfaceHoles   TotalGrayVol  \
# subject                           ...
# 10013         1064.3       695.4  ...            44  592711.111666
# 10013          968.0       454.7  ...            70  592865.003380
# 10019          928.5       667.8  ...            45  667488.665351
# 10026          950.0       450.6  ...            52  606974.728489
# 10032         1060.9       914.8  ...            23  623645.895177
#
#          WM-hypointensities  lhCerebralWhiteMatterVol    lhCortexVol  \
# subject
# 10013                2799.6             211591.434475  221637.861596
# 10013                2948.9             215193.292623  224053.188198
# 10019                1927.9             241968.281419  251468.157656
# 10026                2325.5             214797.860888  238147.069588
# 10032                 894.3             263883.923522  233179.819260
#
#          lhSurfaceHoles  non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject
# 10013                21                       0             209867.261886
# 10013                46                       0             213985.656464
# 10019                28                       0             241150.947036
# 10026                23                       0             215416.673620
# 10032                11                       0             269911.449888
#
#            rhCortexVol  rhSurfaceHoles
# subject
# 10013    224159.250070              23
# 10013    221333.815182              24
# 10019    249285.507695              17
# 10026    236342.658901              29
# 10032    235479.075916              12
#
# [5 rows x 66 columns]

# %%
statsFreeS.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10019           2132.3         2754.8            0.0     22960.8
# 10026           1957.3         2178.0            0.0     20069.7
# 10032            899.8         1068.0            0.0     21077.7
# 10034           1000.5         1658.9            0.0     18384.2
# 10036           2199.7         2524.1            0.0     18645.0
#
# region    BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject
# 10019    1.222108e+06        1.192832e+06        627.5       295.7
# 10026    1.105547e+06        1.054933e+06        671.0       304.7
# 10032    1.212473e+06        1.193060e+06        818.4       457.0
# 10034    1.094593e+06        1.073541e+06        701.7       318.1
# 10036    1.070421e+06        1.019344e+06        682.8       261.7
#
# region   CC_Mid_Anterior  CC_Mid_Posterior  ...  SupraTentorialVolNotVent  \
# subject                                     ...
# 10019              264.2             281.9  ...              1.046722e+06
# 10026              328.3             297.4  ...              9.472373e+05
# 10032              512.6             517.6  ...              1.061598e+06
# 10034              334.5             386.4  ...              9.467748e+05
# 10036              294.3             272.3  ...              8.914106e+05
#
# region    TotalGrayVol  VentricleChoroidVol  WM-hypointensities          eTIV  \
# subject
# 10019    683440.609488         23230.546875              1985.0  1.674232e+06
# 10026    612632.631417         45083.254663              2609.7  1.601848e+06
# 10032    634957.815632         16796.469001              1179.2  1.621333e+06
# 10034    596388.219371         17671.500000              1524.3  1.414327e+06
# 10036    595379.896448         45382.858763              2055.4  1.469776e+06
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10019               240172.382812  253798.614247                     0.0
# 10026               211435.254261  240081.877244                     0.0
# 10032               262423.154931  236897.055211                     0.0
# 10034               225925.031250  222024.116193                     0.0
# 10036               198479.133283  219840.289918                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10019               240514.523438  254927.104616
# 10026               209418.710423  235707.583055
# 10032               268261.736645  239485.893522
# 10034               226789.453125  220406.306303
# 10036               199891.546936  222720.077337
#
# [5 rows x 59 columns]

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#Reshaping the dataframe
statsFreeS_AO = statsFreeS_AO.pivot_table(values='value', index=statsFreeS_AO.index, columns='region', aggfunc='first')

statsFreeS_AO.head()
# Out:
# region   3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject
# 10010           1160.4         1395.3            0.0     23388.7
# 10011           1243.8         1341.1            0.0     20558.4
# 10012           1353.4         1270.0            0.0     20768.9
# 10014           1125.9         1785.2            0.0     18915.4
# 10016            683.2         1219.1            0.0     23868.6
#
# region    BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject
# 10010    1.140177e+06        1.113767e+06        723.8       360.5
# 10011    1.006308e+06        9.865598e+05        520.4       256.3
# 10012    1.070965e+06        1.040016e+06        650.1       278.3
# 10014    1.022134e+06        9.981487e+05        632.1       282.0
# 10016    1.149085e+06        1.135812e+06        718.8       426.6
#
# region   CC_Mid_Anterior  CC_Mid_Posterior  ...  SupraTentorialVolNotVent  \
# subject                                     ...
# 10010              402.9             395.7  ...             963896.625000
# 10011              260.9             253.9  ...             861307.171875
# 10012              296.5             273.8  ...             925893.703125
# 10014              291.7             328.1  ...             860289.187500
# 10016              568.5             428.3  ...             989221.781250
#
# region    TotalGrayVol  VentricleChoroidVol  WM-hypointensities          eTIV  \
# subject
# 10010    620161.819810         22698.140625              1997.8  1.582779e+06
# 10011    579510.277307         15930.000000              1167.6  1.433194e+06
# 10012    588427.472428         27403.312500              1790.8  1.483052e+06
# 10014    593312.287143         20322.562500              2298.5  1.403288e+06
# 10016    632452.131404         10582.734375              1268.9  1.486950e+06
#
# region   lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10010               233609.484375  223312.769133                    12.3
# 10011               189834.468750  213108.455452                     4.0
# 10012               214247.320312  224009.648907                     0.0
# 10014               189531.773438  215815.668491                     0.0
# 10016               235996.875000  228388.463428                     0.0
#
# region   rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10010               228810.234375  220056.003802
# 10011               191989.828125  214773.196854
# 10012               213940.617188  223101.511021
# 10014               189241.523438  216511.649902
# 10016               236187.140625  232136.105476
#
# [5 rows x 59 columns]

# %%
statsFreeS_AO.shape
# Out:
# (1072, 59)

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1184, 66)
# (1072, 59)

# %% [markdown]
# ### Checking common columns in both dataframes (if they are not common, they will be removed)

# %% [markdown]
# #### ALFA_PLUS

# %%
#if a column is not in the other dataframe, it is removed

column_notFastS = []
for column in statsFastS.columns:
    if column == 'Scan':
        continue
    elif column not in statsFreeS.columns:
        print(column)
        column_notFastS.append(column)
    else:
        continue
statsFastS.drop(column_notFastS,axis=1, inplace=True)

column_notFreeS = []
for column in statsFreeS.columns:
    if column not in statsFastS.columns:
        print(column)
        column_notFreeS.append(column)
    else:
        continue
statsFreeS.drop(column_notFreeS,axis=1, inplace=True)
# Out:
# BrainSegVol-to-eTIV
# BrainSegVolNotVentSurf
# CortexVol
# EstimatedTotalIntraCranialVol
# Left-Thalamus-Proper
# MaskVol-to-eTIV
# Right-Thalamus-Proper
# SupraTentorialVolNotVentVox
# SurfaceHoles
# lhSurfaceHoles
# rhSurfaceHoles
# Left-Thalamus
# Right-Thalamus
# VentricleChoroidVol
# eTIV

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#if a column is not in the other dataframe, it is removed

column_notFastS = []
for column in statsFastS_AO.columns:
    if column == 'Scan':
        continue
    elif column not in statsFreeS_AO.columns:
        print(column)
        column_notFastS.append(column)
    else:
        continue
statsFastS_AO.drop(column_notFastS,axis=1, inplace=True)

column_notFreeS = []
for column in statsFreeS_AO.columns:
    if column not in statsFastS_AO.columns:
        print(column)
        column_notFreeS.append(column)
    else:
        continue
statsFreeS_AO.drop(column_notFreeS,axis=1, inplace=True)
# Out:
# BrainSegVol-to-eTIV
# BrainSegVolNotVentSurf
# CortexVol
# EstimatedTotalIntraCranialVol
# Left-Thalamus-Proper
# MaskVol-to-eTIV
# Right-Thalamus-Proper
# SupraTentorialVolNotVentVox
# SurfaceHoles
# lhSurfaceHoles
# rhSurfaceHoles
# Left-Thalamus
# Right-Thalamus
# VentricleChoroidVol
# eTIV

# %% [markdown]
# ### We now see we have the same number of columns in both dataframes:

# %% [markdown]
# #### ALFA_PLUS

# %%
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (391, 55)
# (369, 55)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1184, 55)
# (1072, 55)

# %% [markdown]
# ### Checking common rows in both dataframes (if they are not common, they will be removed)

# %% [markdown]
# #### ALFA_PLUS

# %%
#if a subject is not in the other dataframe, it is removed
indexFreeS = []
for index, row in statsFreeS.iterrows():
    indexFreeS.append(index)
#print(indexFreeS)
indexFastS = []
for index, row in statsFastS.iterrows():
    indexFastS.append(index)
    
print(len(indexFastS))
print(len(indexFreeS))

index_not = []
for i in range(len(indexFastS)):
    if indexFastS[i] not in indexFreeS:
        print(indexFastS[i])
        index_not.append(indexFastS[i])
        #statsFastS.drop(indexFastS[i], inplace=True)

    else:
        continue
statsFastS.drop(index_not, inplace=True)
# Out:
# 391
# 369
# 10013
# 10013
# 10651
# 10651
# 11309
# 11309
# 11491
# 11491
# 11872
# 11872
# 13135
# 13135
# 55395
# 55395
# 66020
# 66020
# 77072
# 77072

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#removing subjects with errors detected out of this notebook
statsFastS_AO.drop([11481,11803,13306], inplace=True)
statsFreeS_AO.drop([11481,11803,13306], inplace=True)

# %%
#if a subject is not in the other dataframe, it is removed
indexFreeS = []
for index, row in statsFreeS_AO.iterrows():
    indexFreeS.append(index)
#print(indexFreeS)
indexFastS = []
for index, row in statsFastS_AO.iterrows():
    indexFastS.append(index)
    
print(len(indexFastS))
print(len(indexFreeS))

index_not = []
for i in range(len(indexFastS)):
    if indexFastS[i] not in indexFreeS:
        print(indexFastS[i])
        index_not.append(indexFastS[i])
        #statsFastS.drop(indexFastS[i], inplace=True)

    else:
        continue
statsFastS_AO.drop(index_not, inplace=True)
# Out:
# 1181
# 1069
# 10310
# 10310
# 10317
# 10317
# 10362
# 10362
# 10393
# 10393
# 10419
# 10419
# 10419
# 10521
# 10521
# 10556
# 10811
# 10811
# 10942
# 10942
# 10971
# 10971
# 11325
# 11325
# 11325
# 11332
# 11332
# 11614
# 11657
# 11657
# 11686
# 11686
# 11686
# 11807
# 12056
# 12056
# 12278
# 12278
# 12332
# 12521
# 12787
# 12787
# 12801
# 12801
# 13096
# 13096
# 13127
# 13320
# 13345
# 21026
# 21026
# 21085
# 21085
# 44058
# 44092
# 44159
# 44159
# 44277
# 44289
# 44289
# 44331
# 44331
# 44343
# 44343
# 44393
# 44393
# 44494
# 44494
# 44632
# 44632
# 44632
# 44846
# 55062
# 55114
# 55202
# 55202
# 55289
# 55289
# 55687
# 55687
# 55687
# 55874
# 55874
# 66015
# 66015
# 66015
# 66068
# 66095
# 66095
# 66104
# 66104
# 66137
# 66137
# 66145
# 66145
# 66159
# 66159
# 66274
# 66274
# 66286
# 66286
# 77040
# 77040
# 77131
# 77131
# 77179
# 77209
# 77209

# %% [markdown]
# ### The number of rows have decreased in FastSurfer stats' dataframe. We will need to check later if there are any duplicated subjects

# %% [markdown]
# #### ALFA_PLUS

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (373, 55)
# (369, 55)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1075, 55)
# (1069, 55)

# %% [markdown]
# ### Removing those rows that are duplicated. We print the index location and then we remove them

# %% [markdown]
# #### ALFA_PLUS

# %%
lista = statsFastS.index.duplicated().tolist()
for i in [i for i,x in enumerate(lista) if x == 1]:
    print(i)
    
statsFastS = statsFastS[~statsFastS.index.duplicated(keep='first')] #removing duplicated subjects
# Out:
# 83
# 161
# 206
# 285

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
lista = statsFastS_AO.index.duplicated().tolist()
for i in [i for i,x in enumerate(lista) if x == 1]:
    print(i)
    
statsFastS_AO = statsFastS_AO[~statsFastS_AO.index.duplicated(keep='first')] #removing duplicated subjects
# Out:
# 160
# 195
# 253
# 860
# 916
# 1019

# %% [markdown]
# ### Now, we can see we have the same shape in both DataFrames

# %% [markdown]
# #### ALFA_PLUS

# %%
#shapes
print(statsFastS.shape)
print(statsFreeS.shape)
# Out:
# (369, 55)
# (369, 55)

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#shapes
print(statsFastS_AO.shape)
print(statsFreeS_AO.shape)
# Out:
# (1069, 55)
# (1069, 55)

# %% [markdown]
# ## Concatenation of subjects from both datasets

# %%
statsFastSurfer = pd.concat([statsFastS,statsFastS_AO]).sort_index()

# %%
statsFastSurfer.head()
# Out:
#          3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  BrainSegVol  \
# subject
# 10010           1252.3         1545.0              0     23478.7      1130872
# 10011           1395.7         1464.9              0     20967.4      1013429
# 10012           1373.6         1385.9              0     21221.4      1074364
# 10014           1262.1         2172.9              0     19249.0      1004189
# 10016            869.7         1429.4              0     23659.8      1141082
#
#          BrainSegVolNotVent  CC_Anterior  CC_Central  CC_Mid_Anterior  \
# subject
# 10010               1103652       1159.2       914.5            541.8
# 10011                993032        703.7       339.2            350.5
# 10012               1042517        981.2       712.4            388.5
# 10014                976928        870.0       467.3            390.2
# 10016               1125395        932.0       754.3            907.2
#
#          CC_Mid_Posterior  ...  SubCortGrayVol  SupraTentorialVol  \
# subject                    ...
# 10010               550.7  ...           58464       9.853291e+05
# 10011               329.4  ...           50086       8.956513e+05
# 10012               462.9  ...           51157       9.587228e+05
# 10014               470.3  ...           46262       8.753833e+05
# 10016               612.9  ...           55147       1.006365e+06
#
#          SupraTentorialVolNotVent   TotalGrayVol  WM-hypointensities  \
# subject
# 10010               962081.127032  606493.534351              2402.2
# 10011               879223.319629  579274.765061              1071.5
# 10012               930585.844341  584596.562471              1390.8
# 10014               852697.330292  575611.222570              1768.0
# 10016               994089.588492  617534.940919              1362.1
#
#          lhCerebralWhiteMatterVol    lhCortexVol  non-WM-hypointensities  \
# subject
# 10010               235160.339637  220400.716587                       0
# 10011               195681.058639  218365.416744                       0
# 10012               215145.144558  219214.854598                       0
# 10014               189803.693081  210816.581235                       0
# 10016               240852.456984  227261.584722                       0
#
#          rhCerebralWhiteMatterVol    rhCortexVol
# subject
# 10010               231447.253043  215464.817764
# 10011               196481.495929  217480.348316
# 10012               218237.137312  225925.707873
# 10014               190448.414641  214557.641335
# 10016               240181.190589  229525.356198
#
# [5 rows x 55 columns]

# %%
statsFastSurfer.shape
# Out:
# (1438, 55)

# %% [markdown]
# ### Adding a new column ('Software') in FreeSurfer stats' DataFrame and setting it as index, along with 'subject'

# %% [markdown]
# #### ALFA_PLUS

# %%
#we set both subject and Software as index in statsFreeS

statsFreeS['Software'] = 'FreeSurfer'
statsFreeS.reset_index(inplace=True)
statsFreeS.set_index(['subject','Software'], inplace= True)

# %%
statsFreeS.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10019   FreeSurfer         2132.3         2754.8            0.0     22960.8
# 10026   FreeSurfer         1957.3         2178.0            0.0     20069.7
# 10032   FreeSurfer          899.8         1068.0            0.0     21077.7
# 10034   FreeSurfer         1000.5         1658.9            0.0     18384.2
# 10036   FreeSurfer         2199.7         2524.1            0.0     18645.0
#
# region               BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject Software
# 10019   FreeSurfer  1.222108e+06        1.192832e+06        627.5       295.7
# 10026   FreeSurfer  1.105547e+06        1.054933e+06        671.0       304.7
# 10032   FreeSurfer  1.212473e+06        1.193060e+06        818.4       457.0
# 10034   FreeSurfer  1.094593e+06        1.073541e+06        701.7       318.1
# 10036   FreeSurfer  1.070421e+06        1.019344e+06        682.8       261.7
#
# region              CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# subject Software                                       ...
# 10019   FreeSurfer            264.2             281.9  ...    58275.281250
# 10026   FreeSurfer            328.3             297.4  ...    50929.544310
# 10032   FreeSurfer            512.6             517.6  ...    55463.995112
# 10034   FreeSurfer            334.5             386.4  ...    52496.015625
# 10036   FreeSurfer            294.3             272.3  ...    50932.108820
#
# region              SupraTentorialVol  SupraTentorialVolNotVent  \
# subject Software
# 10019   FreeSurfer       1.075999e+06              1.046722e+06
# 10026   FreeSurfer       9.978513e+05              9.472373e+05
# 10032   FreeSurfer       1.081012e+06              1.061598e+06
# 10034   FreeSurfer       9.678268e+05              9.467748e+05
# 10036   FreeSurfer       9.424870e+05              8.914106e+05
#
# region               TotalGrayVol  WM-hypointensities  \
# subject Software
# 10019   FreeSurfer  683440.609488              1985.0
# 10026   FreeSurfer  612632.631417              2609.7
# 10032   FreeSurfer  634957.815632              1179.2
# 10034   FreeSurfer  596388.219371              1524.3
# 10036   FreeSurfer  595379.896448              2055.4
#
# region              lhCerebralWhiteMatterVol    lhCortexVol  \
# subject Software
# 10019   FreeSurfer             240172.382812  253798.614247
# 10026   FreeSurfer             211435.254261  240081.877244
# 10032   FreeSurfer             262423.154931  236897.055211
# 10034   FreeSurfer             225925.031250  222024.116193
# 10036   FreeSurfer             198479.133283  219840.289918
#
# region              non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject Software
# 10019   FreeSurfer                     0.0             240514.523438
# 10026   FreeSurfer                     0.0             209418.710423
# 10032   FreeSurfer                     0.0             268261.736645
# 10034   FreeSurfer                     0.0             226789.453125
# 10036   FreeSurfer                     0.0             199891.546936
#
# region                rhCortexVol
# subject Software
# 10019   FreeSurfer  254927.104616
# 10026   FreeSurfer  235707.583055
# 10032   FreeSurfer  239485.893522
# 10034   FreeSurfer  220406.306303
# 10036   FreeSurfer  222720.077337
#
# [5 rows x 55 columns]

# %% [markdown]
# #### ALFA_OPCIONAL

# %%
#we set both subject and Software as index in statsFreeS

statsFreeS_AO['Software'] = 'FreeSurfer'
statsFreeS_AO.reset_index(inplace=True)
statsFreeS_AO.set_index(['subject','Software'], inplace= True)

# %%
statsFreeS_AO.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FreeSurfer         1160.4         1395.3            0.0     23388.7
# 10011   FreeSurfer         1243.8         1341.1            0.0     20558.4
# 10012   FreeSurfer         1353.4         1270.0            0.0     20768.9
# 10014   FreeSurfer         1125.9         1785.2            0.0     18915.4
# 10016   FreeSurfer          683.2         1219.1            0.0     23868.6
#
# region               BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject Software
# 10010   FreeSurfer  1.140177e+06        1.113767e+06        723.8       360.5
# 10011   FreeSurfer  1.006308e+06        9.865598e+05        520.4       256.3
# 10012   FreeSurfer  1.070965e+06        1.040016e+06        650.1       278.3
# 10014   FreeSurfer  1.022134e+06        9.981487e+05        632.1       282.0
# 10016   FreeSurfer  1.149085e+06        1.135812e+06        718.8       426.6
#
# region              CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# subject Software                                       ...
# 10010   FreeSurfer            402.9             395.7  ...    58854.093750
# 10011   FreeSurfer            260.9             253.9  ...    51836.203125
# 10012   FreeSurfer            296.5             273.8  ...    51178.921875
# 10014   FreeSurfer            291.7             328.1  ...    49515.890625
# 10016   FreeSurfer            568.5             428.3  ...    57408.750000
#
# region              SupraTentorialVol  SupraTentorialVolNotVent  \
# subject Software
# 10010   FreeSurfer       9.903064e+05             963896.625000
# 10011   FreeSurfer       8.810556e+05             861307.171875
# 10012   FreeSurfer       9.568429e+05             925893.703125
# 10014   FreeSurfer       8.842740e+05             860289.187500
# 10016   FreeSurfer       1.002495e+06             989221.781250
#
# region               TotalGrayVol  WM-hypointensities  \
# subject Software
# 10010   FreeSurfer  620161.819810              1997.8
# 10011   FreeSurfer  579510.277307              1167.6
# 10012   FreeSurfer  588427.472428              1790.8
# 10014   FreeSurfer  593312.287143              2298.5
# 10016   FreeSurfer  632452.131404              1268.9
#
# region              lhCerebralWhiteMatterVol    lhCortexVol  \
# subject Software
# 10010   FreeSurfer             233609.484375  223312.769133
# 10011   FreeSurfer             189834.468750  213108.455452
# 10012   FreeSurfer             214247.320312  224009.648907
# 10014   FreeSurfer             189531.773438  215815.668491
# 10016   FreeSurfer             235996.875000  228388.463428
#
# region              non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject Software
# 10010   FreeSurfer                    12.3             228810.234375
# 10011   FreeSurfer                     4.0             191989.828125
# 10012   FreeSurfer                     0.0             213940.617188
# 10014   FreeSurfer                     0.0             189241.523438
# 10016   FreeSurfer                     0.0             236187.140625
#
# region                rhCortexVol
# subject Software
# 10010   FreeSurfer  220056.003802
# 10011   FreeSurfer  214773.196854
# 10012   FreeSurfer  223101.511021
# 10014   FreeSurfer  216511.649902
# 10016   FreeSurfer  232136.105476
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Adding the column 'Software' in FastSurfer stats' DataFrame and setting it as index, along with 'subject'

# %%
#we set both subject and Software as index in statsFastS

statsFastSurfer['Software'] ='FastSurfer'
statsFastSurfer.reset_index(inplace=True)
statsFastSurfer.set_index(['subject','Software'], inplace= True)

# %%
statsFastSurfer.head()
# Out:
#                     3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FastSurfer         1252.3         1545.0              0     23478.7
# 10011   FastSurfer         1395.7         1464.9              0     20967.4
# 10012   FastSurfer         1373.6         1385.9              0     21221.4
# 10014   FastSurfer         1262.1         2172.9              0     19249.0
# 10016   FastSurfer          869.7         1429.4              0     23659.8
#
#                     BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject Software
# 10010   FastSurfer      1130872             1103652       1159.2       914.5
# 10011   FastSurfer      1013429              993032        703.7       339.2
# 10012   FastSurfer      1074364             1042517        981.2       712.4
# 10014   FastSurfer      1004189              976928        870.0       467.3
# 10016   FastSurfer      1141082             1125395        932.0       754.3
#
#                     CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# subject Software                                       ...
# 10010   FastSurfer            541.8             550.7  ...           58464
# 10011   FastSurfer            350.5             329.4  ...           50086
# 10012   FastSurfer            388.5             462.9  ...           51157
# 10014   FastSurfer            390.2             470.3  ...           46262
# 10016   FastSurfer            907.2             612.9  ...           55147
#
#                     SupraTentorialVol  SupraTentorialVolNotVent  \
# subject Software
# 10010   FastSurfer       9.853291e+05             962081.127032
# 10011   FastSurfer       8.956513e+05             879223.319629
# 10012   FastSurfer       9.587228e+05             930585.844341
# 10014   FastSurfer       8.753833e+05             852697.330292
# 10016   FastSurfer       1.006365e+06             994089.588492
#
#                      TotalGrayVol  WM-hypointensities  \
# subject Software
# 10010   FastSurfer  606493.534351              2402.2
# 10011   FastSurfer  579274.765061              1071.5
# 10012   FastSurfer  584596.562471              1390.8
# 10014   FastSurfer  575611.222570              1768.0
# 10016   FastSurfer  617534.940919              1362.1
#
#                     lhCerebralWhiteMatterVol    lhCortexVol  \
# subject Software
# 10010   FastSurfer             235160.339637  220400.716587
# 10011   FastSurfer             195681.058639  218365.416744
# 10012   FastSurfer             215145.144558  219214.854598
# 10014   FastSurfer             189803.693081  210816.581235
# 10016   FastSurfer             240852.456984  227261.584722
#
#                     non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject Software
# 10010   FastSurfer                       0             231447.253043
# 10011   FastSurfer                       0             196481.495929
# 10012   FastSurfer                       0             218237.137312
# 10014   FastSurfer                       0             190448.414641
# 10016   FastSurfer                       0             240181.190589
#
#                       rhCortexVol
# subject Software
# 10010   FastSurfer  215464.817764
# 10011   FastSurfer  217480.348316
# 10012   FastSurfer  225925.707873
# 10014   FastSurfer  214557.641335
# 10016   FastSurfer  229525.356198
#
# [5 rows x 55 columns]

# %% [markdown]
# # 3. Describing FreeSurfer subjects stats

# %% [markdown]
# ## Concatenation of subjects from both datasets

# %%
statsFreeSurfer = pd.concat([statsFreeS,statsFreeS_AO]).sort_index()

# %%
statsFreeSurfer.head()
# Out:
# region              3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FreeSurfer         1160.4         1395.3            0.0     23388.7
# 10011   FreeSurfer         1243.8         1341.1            0.0     20558.4
# 10012   FreeSurfer         1353.4         1270.0            0.0     20768.9
# 10014   FreeSurfer         1125.9         1785.2            0.0     18915.4
# 10016   FreeSurfer          683.2         1219.1            0.0     23868.6
#
# region               BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject Software
# 10010   FreeSurfer  1.140177e+06        1.113767e+06        723.8       360.5
# 10011   FreeSurfer  1.006308e+06        9.865598e+05        520.4       256.3
# 10012   FreeSurfer  1.070965e+06        1.040016e+06        650.1       278.3
# 10014   FreeSurfer  1.022134e+06        9.981487e+05        632.1       282.0
# 10016   FreeSurfer  1.149085e+06        1.135812e+06        718.8       426.6
#
# region              CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# subject Software                                       ...
# 10010   FreeSurfer            402.9             395.7  ...    58854.093750
# 10011   FreeSurfer            260.9             253.9  ...    51836.203125
# 10012   FreeSurfer            296.5             273.8  ...    51178.921875
# 10014   FreeSurfer            291.7             328.1  ...    49515.890625
# 10016   FreeSurfer            568.5             428.3  ...    57408.750000
#
# region              SupraTentorialVol  SupraTentorialVolNotVent  \
# subject Software
# 10010   FreeSurfer       9.903064e+05             963896.625000
# 10011   FreeSurfer       8.810556e+05             861307.171875
# 10012   FreeSurfer       9.568429e+05             925893.703125
# 10014   FreeSurfer       8.842740e+05             860289.187500
# 10016   FreeSurfer       1.002495e+06             989221.781250
#
# region               TotalGrayVol  WM-hypointensities  \
# subject Software
# 10010   FreeSurfer  620161.819810              1997.8
# 10011   FreeSurfer  579510.277307              1167.6
# 10012   FreeSurfer  588427.472428              1790.8
# 10014   FreeSurfer  593312.287143              2298.5
# 10016   FreeSurfer  632452.131404              1268.9
#
# region              lhCerebralWhiteMatterVol    lhCortexVol  \
# subject Software
# 10010   FreeSurfer             233609.484375  223312.769133
# 10011   FreeSurfer             189834.468750  213108.455452
# 10012   FreeSurfer             214247.320312  224009.648907
# 10014   FreeSurfer             189531.773438  215815.668491
# 10016   FreeSurfer             235996.875000  228388.463428
#
# region              non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject Software
# 10010   FreeSurfer                    12.3             228810.234375
# 10011   FreeSurfer                     4.0             191989.828125
# 10012   FreeSurfer                     0.0             213940.617188
# 10014   FreeSurfer                     0.0             189241.523438
# 10016   FreeSurfer                     0.0             236187.140625
#
# region                rhCortexVol
# subject Software
# 10010   FreeSurfer  220056.003802
# 10011   FreeSurfer  214773.196854
# 10012   FreeSurfer  223101.511021
# 10014   FreeSurfer  216511.649902
# 10016   FreeSurfer  232136.105476
#
# [5 rows x 55 columns]

# %%
#shape
statsFreeSurfer.shape
# Out:
# (1438, 55)

# %%
statsFastSurfer.shape
# Out:
# (1438, 55)

# %% [markdown]
# ### Describing FreeSurfer stats' DataFrame

# %%
statsFreeSurfer.describe()
# Out:
# region  3rd-Ventricle  4th-Ventricle  5th-Ventricle    Brain-Stem  \
# count     1438.000000    1438.000000    1438.000000   1438.000000
# mean      1271.105772    1728.353825       0.006606  20758.860987
# std        475.425261     485.390388       0.100407   2264.690611
# min        460.800000     663.400000       0.000000  14782.600000
# 25%        926.150000    1390.850000       0.000000  19149.475000
# 50%       1174.000000    1635.200000       0.000000  20590.200000
# 75%       1517.625000    1972.875000       0.000000  22257.500000
# max       4280.100000    6076.800000       2.600000  28267.700000
#
# region   BrainSegVol  BrainSegVolNotVent  CC_Anterior   CC_Central  \
# count   1.438000e+03        1.438000e+03  1438.000000  1438.000000
# mean    1.077927e+06        1.051012e+06   655.430250   347.693046
# std     1.035261e+05        1.000692e+05   110.173509    71.743448
# min     7.908794e+05        7.683449e+05   342.700000   183.100000
# 25%     1.003575e+06        9.793147e+05   581.750000   299.875000
# 50%     1.070721e+06        1.043777e+06   648.200000   335.800000
# 75%     1.147223e+06        1.118211e+06   728.625000   379.600000
# max     1.380311e+06        1.345575e+06  1015.400000   785.200000
#
# region  CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# count       1438.000000       1438.000000  ...     1438.000000
# mean         354.973018        353.286787  ...    53420.471232
# std           80.272289         75.203252  ...     4744.669903
# min          173.700000        164.800000  ...    40100.727559
# 25%          302.200000        298.025000  ...    50082.046875
# 50%          341.750000        347.150000  ...    53026.686874
# 75%          391.000000        402.650000  ...    56611.232531
# max          825.500000        632.300000  ...    68864.468873
#
# region  SupraTentorialVol  SupraTentorialVolNotVent   TotalGrayVol  \
# count        1.438000e+03              1.438000e+03    1438.000000
# mean         9.483369e+05              9.214166e+05  600826.018309
# std          9.521700e+04              9.173731e+04   51468.306167
# min          6.828178e+05              6.602833e+05  452892.873545
# 25%          8.798531e+05              8.556985e+05  564804.838512
# 50%          9.422911e+05              9.151681e+05  596627.214265
# 75%          1.009581e+06              9.820506e+05  633108.835617
# max          1.238721e+06              1.190503e+06  778846.692866
#
# region  WM-hypointensities  lhCerebralWhiteMatterVol    lhCortexVol  \
# count          1438.000000               1438.000000    1438.000000
# mean           2532.918289             212269.100707  222239.905407
# std            2187.784934              25513.293651   20534.770276
# min             666.600000             144264.434023  164191.142684
# 25%            1549.725000             193127.179801  208141.128615
# 50%            1976.650000             210723.425008  220860.709282
# 75%            2663.225000             230384.828635  234783.435814
# max           29943.400000             302429.320312  297496.375263
#
# region  non-WM-hypointensities  rhCerebralWhiteMatterVol    rhCortexVol
# count              1438.000000               1438.000000    1438.000000
# mean                  0.718081             212049.635025  222164.926835
# std                   2.673045              25449.822484   20564.514829
# min                   0.000000             143647.918584  160374.527736
# 25%                   0.000000             193330.127494  208078.760034
# 50%                   0.000000             210558.023438  220525.024656
# 75%                   0.000000             229227.837891  235336.981459
# max                  35.800000             299234.460938  302706.476319
#
# [8 rows x 55 columns]

# %% [markdown]
# ### Correlation map to check if variables are correlated

# %%
#Correlation Map

f, ax = plt.subplots(figsize=(50, 50))
corr = statsFreeSurfer.corr()
sns.heatmap(corr,annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# # 4. Creating a common DataFrame with FreeSurfer and FastSurfer stats

# %% [markdown]
# ### Concatenating both DataFrames to put them together

# %%
concat_df = pd.concat([statsFastSurfer,statsFreeSurfer]).sort_index()

concat_df.head(10)
# Out:
#                     3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# subject Software
# 10010   FastSurfer         1252.3         1545.0            0.0     23478.7
#         FreeSurfer         1160.4         1395.3            0.0     23388.7
# 10011   FastSurfer         1395.7         1464.9            0.0     20967.4
#         FreeSurfer         1243.8         1341.1            0.0     20558.4
# 10012   FastSurfer         1373.6         1385.9            0.0     21221.4
#         FreeSurfer         1353.4         1270.0            0.0     20768.9
# 10014   FastSurfer         1262.1         2172.9            0.0     19249.0
#         FreeSurfer         1125.9         1785.2            0.0     18915.4
# 10016   FastSurfer          869.7         1429.4            0.0     23659.8
#         FreeSurfer          683.2         1219.1            0.0     23868.6
#
#                      BrainSegVol  BrainSegVolNotVent  CC_Anterior  CC_Central  \
# subject Software
# 10010   FastSurfer  1.130872e+06        1.103652e+06       1159.2       914.5
#         FreeSurfer  1.140177e+06        1.113767e+06        723.8       360.5
# 10011   FastSurfer  1.013429e+06        9.930320e+05        703.7       339.2
#         FreeSurfer  1.006308e+06        9.865598e+05        520.4       256.3
# 10012   FastSurfer  1.074364e+06        1.042517e+06        981.2       712.4
#         FreeSurfer  1.070965e+06        1.040016e+06        650.1       278.3
# 10014   FastSurfer  1.004189e+06        9.769280e+05        870.0       467.3
#         FreeSurfer  1.022134e+06        9.981487e+05        632.1       282.0
# 10016   FastSurfer  1.141082e+06        1.125395e+06        932.0       754.3
#         FreeSurfer  1.149085e+06        1.135812e+06        718.8       426.6
#
#                     CC_Mid_Anterior  CC_Mid_Posterior  ...  SubCortGrayVol  \
# subject Software                                       ...
# 10010   FastSurfer            541.8             550.7  ...    58464.000000
#         FreeSurfer            402.9             395.7  ...    58854.093750
# 10011   FastSurfer            350.5             329.4  ...    50086.000000
#         FreeSurfer            260.9             253.9  ...    51836.203125
# 10012   FastSurfer            388.5             462.9  ...    51157.000000
#         FreeSurfer            296.5             273.8  ...    51178.921875
# 10014   FastSurfer            390.2             470.3  ...    46262.000000
#         FreeSurfer            291.7             328.1  ...    49515.890625
# 10016   FastSurfer            907.2             612.9  ...    55147.000000
#         FreeSurfer            568.5             428.3  ...    57408.750000
#
#                     SupraTentorialVol  SupraTentorialVolNotVent  \
# subject Software
# 10010   FastSurfer       9.853291e+05             962081.127032
#         FreeSurfer       9.903064e+05             963896.625000
# 10011   FastSurfer       8.956513e+05             879223.319629
#         FreeSurfer       8.810556e+05             861307.171875
# 10012   FastSurfer       9.587228e+05             930585.844341
#         FreeSurfer       9.568429e+05             925893.703125
# 10014   FastSurfer       8.753833e+05             852697.330292
#         FreeSurfer       8.842740e+05             860289.187500
# 10016   FastSurfer       1.006365e+06             994089.588492
#         FreeSurfer       1.002495e+06             989221.781250
#
#                      TotalGrayVol  WM-hypointensities  \
# subject Software
# 10010   FastSurfer  606493.534351              2402.2
#         FreeSurfer  620161.819810              1997.8
# 10011   FastSurfer  579274.765061              1071.5
#         FreeSurfer  579510.277307              1167.6
# 10012   FastSurfer  584596.562471              1390.8
#         FreeSurfer  588427.472428              1790.8
# 10014   FastSurfer  575611.222570              1768.0
#         FreeSurfer  593312.287143              2298.5
# 10016   FastSurfer  617534.940919              1362.1
#         FreeSurfer  632452.131404              1268.9
#
#                     lhCerebralWhiteMatterVol    lhCortexVol  \
# subject Software
# 10010   FastSurfer             235160.339637  220400.716587
#         FreeSurfer             233609.484375  223312.769133
# 10011   FastSurfer             195681.058639  218365.416744
#         FreeSurfer             189834.468750  213108.455452
# 10012   FastSurfer             215145.144558  219214.854598
#         FreeSurfer             214247.320312  224009.648907
# 10014   FastSurfer             189803.693081  210816.581235
#         FreeSurfer             189531.773438  215815.668491
# 10016   FastSurfer             240852.456984  227261.584722
#         FreeSurfer             235996.875000  228388.463428
#
#                     non-WM-hypointensities  rhCerebralWhiteMatterVol  \
# subject Software
# 10010   FastSurfer                     0.0             231447.253043
#         FreeSurfer                    12.3             228810.234375
# 10011   FastSurfer                     0.0             196481.495929
#         FreeSurfer                     4.0             191989.828125
# 10012   FastSurfer                     0.0             218237.137312
#         FreeSurfer                     0.0             213940.617188
# 10014   FastSurfer                     0.0             190448.414641
#         FreeSurfer                     0.0             189241.523438
# 10016   FastSurfer                     0.0             240181.190589
#         FreeSurfer                     0.0             236187.140625
#
#                       rhCortexVol
# subject Software
# 10010   FastSurfer  215464.817764
#         FreeSurfer  220056.003802
# 10011   FastSurfer  217480.348316
#         FreeSurfer  214773.196854
# 10012   FastSurfer  225925.707873
#         FreeSurfer  223101.511021
# 10014   FastSurfer  214557.641335
#         FreeSurfer  216511.649902
# 10016   FastSurfer  229525.356198
#         FreeSurfer  232136.105476
#
# [10 rows x 55 columns]

# %%
concat_df.shape
# Out:
# (2876, 55)

# %% [markdown]
# ### Saving the DataFrame to analyse it in other notebook

# %%
concat_df.to_pickle('all_stats_f7.pkl')

# %%
statsFastSurfer.to_pickle('statsFastSurfer_f7.pkl')
statsFreeSurfer.to_pickle('statsFreeSurfer_f7.pkl')

# %%
concat_df.to_excel('all_stats_f7.xlsx')
statsFastSurfer.to_excel('statsFastSurfer_f7.xlsx')
statsFreeSurfer.to_excel('statsFreeSurfer.xlsx')
